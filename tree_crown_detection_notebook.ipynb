# %% [markdown]
# # Tree Crown Detection using Mask R-CNN
#
# This notebook implements a tree crown detection model using Mask R-CNN based on the methodology described in the paper. The model can detect and map tree crowns from Google Earth images.
#
# ## Setup and Dependencies

# %%
# Install required packages if needed
# !pip install tensorflow
# !pip install numpy
# !pip install opencv-python==4.7.0.72
# !pip install scikit-image
# !pip install matplotlib
# Out:
# ERROR: Could not find a version that satisfies the requirement tf-nightly (from versions: none)
#
# [notice] A new release of pip is available: 25.0 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip
# ERROR: No matching distribution found for tf-nightly

# %%
# !pip freeze #> requirements.txt
# Out:
# absl-py==2.1.0
# anyio==4.8.0
# appnope==0.1.4
# argon2-cffi==23.1.0
# argon2-cffi-bindings==21.2.0
# arrow==1.3.0
# asttokens==3.0.0
# astunparse==1.6.3
# async-lru==2.0.4
# attrs==25.1.0
# babel==2.17.0
# beautifulsoup4==4.13.3
# bleach==6.2.0
# certifi==2025.1.31
# cffi==1.17.1
# charset-normalizer==3.4.1
# comm==0.2.2
# contourpy==1.3.1
# cycler==0.12.1
# debugpy==1.8.13
# decorator==5.2.1
# defusedxml==0.7.1
# executing==2.2.0
# fastjsonschema==2.21.1
# flatbuffers==25.2.10
# fonttools==4.56.0
# fqdn==1.5.1
# gast==0.6.0
# google-pasta==0.2.0
# grpcio==1.70.0
# h11==0.14.0
# h5py==3.13.0
# httpcore==1.0.7
# httpx==0.28.1
# idna==3.10
# imageio==2.37.0
# ipykernel==6.29.5
# ipython==9.0.1
# ipython_pygments_lexers==1.1.1
# ipywidgets==8.1.5
# isoduration==20.11.0
# jedi==0.19.2
# Jinja2==3.1.5
# json5==0.10.0
# jsonpointer==3.0.0
# jsonschema==4.23.0
# jsonschema-specifications==2024.10.1
# jupyter==1.1.1
# jupyter-console==6.6.3
# jupyter-events==0.12.0
# jupyter-lsp==2.2.5
# jupyter_client==8.6.3
# jupyter_core==5.7.2
# jupyter_server==2.15.0
# jupyter_server_terminals==0.5.3
# jupyterlab==4.3.5
# jupyterlab_pygments==0.3.0
# jupyterlab_server==2.27.3
# jupyterlab_widgets==3.0.13
# keras==3.9.0
# kiwisolver==1.4.8
# lazy_loader==0.4
# libclang==18.1.1
# Markdown==3.7
# markdown-it-py==3.0.0
# MarkupSafe==3.0.2
# -e git+https://github.com/matterport/Mask_RCNN.git@3deaec5d902d16e1daf56b62d5971d428dc920bc#egg=mask_rcnn
# matplotlib==3.10.1
# matplotlib-inline==0.1.7
# mdurl==0.1.2
# mistune==3.1.2
# ml-dtypes==0.4.1
# namex==0.0.8
# nbclient==0.10.2
# nbconvert==7.16.6
# nbformat==5.10.4
# nest-asyncio==1.6.0
# networkx==3.4.2
# notebook==7.3.2
# notebook_shim==0.2.4
# numpy==2.0.2
# opencv-python==4.11.0.86
# opt_einsum==3.4.0
# optree==0.14.1
# overrides==7.7.0
# packaging==24.2
# pandocfilters==1.5.1
# parso==0.8.4
# pexpect==4.9.0
# pillow==11.1.0
# platformdirs==4.3.6
# prometheus_client==0.21.1
# prompt_toolkit==3.0.50
# protobuf==5.29.3
# psutil==7.0.0
# ptyprocess==0.7.0
# pure_eval==0.2.3
# pycparser==2.22
# Pygments==2.19.1
# pyparsing==3.2.1
# python-dateutil==2.9.0.post0
# python-json-logger==3.2.1
# PyYAML==6.0.2
# pyzmq==26.2.1
# referencing==0.36.2
# requests==2.32.3
# rfc3339-validator==0.1.4
# rfc3986-validator==0.1.1
# rich==13.9.4
# rpds-py==0.23.1
# scikit-image==0.25.2
# scipy==1.15.2
# Send2Trash==1.8.3
# six==1.17.0
# sniffio==1.3.1
# soupsieve==2.6
# stack-data==0.6.3
# tensorboard==2.18.0
# tensorboard-data-server==0.7.2
# tensorflow==2.18.0
# tensorflow-io-gcs-filesystem==0.37.1
# termcolor==2.5.0
# terminado==0.18.1
# tifffile==2025.2.18
# tinycss2==1.4.0
# tornado==6.4.2
# traitlets==5.14.3
# types-python-dateutil==2.9.0.20241206
# typing_extensions==4.12.2
# uri-template==1.3.0
# urllib3==2.3.0
# wcwidth==0.2.13
# webcolors==24.11.1
# webencodings==0.5.1
# websocket-client==1.8.0
# Werkzeug==3.1.3
# widgetsnbextension==4.0.13
# wrapt==1.17.2

# %%
# Clone Mask RCNN repository if not already installed
# !git clone https://github.com/matterport/Mask_RCNN.git
# !pip install -e Mask_RCNN
# Out:
# Cloning into 'Mask_RCNN'...
# remote: Enumerating objects: 956, done.
# remote: Total 956 (delta 0), reused 0 (delta 0), pack-reused 956 (from 1)
# Receiving objects: 100% (956/956), 137.67 MiB | 9.23 MiB/s, done.
# Resolving deltas: 100% (558/558), done.
# Obtaining file:///Users/dynamicpacific/Dropbox/DEV/forestai-platform-model/Mask_RCNN
#   Preparing metadata (setup.py) ... done
# Installing collected packages: mask-rcnn
#   Running setup.py develop for mask-rcnn
# Successfully installed mask-rcnn-2.1
#
# [notice] A new release of pip is available: 23.2.1 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
# Add Mask_RCNN to Python path
import os
import sys
import numpy as np
import tensorflow as tf
from tensorflow import keras
import cv2
import matplotlib.pyplot as plt
import random
import math
import re
import time
import skimage.draw
import skimage.io
import json
# Add the repository's root directory to Python path
repo_dir = os.path.abspath("./Mask_RCNN")
if repo_dir not in sys.path:
    sys.path.append(repo_dir)

# Now try importing
from mrcnn.config import Config
print("Import successful!")
# Out:
# Import successful!

# %% [markdown]
# ## Configuration
#
# Set up the directory structure and configure paths.

# %%
import os
import ssl
import urllib.request

# Temporarily disable SSL verification (use with caution)
ssl._create_default_https_context = ssl._create_unverified_context

# Set file paths
ROOT_DIR = os.path.abspath("./")
COCO_MODEL_PATH = os.path.join(ROOT_DIR, "mask_rcnn_coco.h5")

# Download weights if needed
if not os.path.exists(COCO_MODEL_PATH):
    print("Downloading COCO weights...")
    urllib.request.urlretrieve(
        "https://github.com/matterport/Mask_RCNN/releases/download/v2.0/mask_rcnn_coco.h5",
        COCO_MODEL_PATH
    )
    print("Download completed.")
# Out:
# Downloading COCO weights...
# Download completed.

# %% [markdown]
# ## Use the existing model to test how it works

# %%
# !pip install keras==2.2.4
# Out:
# Collecting keras==2.2.4
#   Obtaining dependency information for keras==2.2.4 from https://files.pythonhosted.org/packages/5e/10/aa32dad071ce52b5502266b5c659451cfd6ffcbf14e6c8c4f16c0ff5aaab/Keras-2.2.4-py2.py3-none-any.whl.metadata
#   Downloading Keras-2.2.4-py2.py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: numpy>=1.9.1 in ./tf_env_py311/lib/python3.11/site-packages (from keras==2.2.4) (2.0.2)
# Requirement already satisfied: scipy>=0.14 in ./tf_env_py311/lib/python3.11/site-packages (from keras==2.2.4) (1.15.2)
# Requirement already satisfied: six>=1.9.0 in ./tf_env_py311/lib/python3.11/site-packages (from keras==2.2.4) (1.17.0)
# Requirement already satisfied: pyyaml in ./tf_env_py311/lib/python3.11/site-packages (from keras==2.2.4) (6.0.2)
# Requirement already satisfied: h5py in ./tf_env_py311/lib/python3.11/site-packages (from keras==2.2.4) (3.13.0)
# Collecting keras-applications>=1.0.6 (from keras==2.2.4)
#   Obtaining dependency information for keras-applications>=1.0.6 from https://files.pythonhosted.org/packages/71/e3/19762fdfc62877ae9102edf6342d71b28fbfd9dea3d2f96a882ce099b03f/Keras_Applications-1.0.8-py3-none-any.whl.metadata
#   Downloading Keras_Applications-1.0.8-py3-none-any.whl.metadata (1.7 kB)
# Collecting keras-preprocessing>=1.0.5 (from keras==2.2.4)
#   Obtaining dependency information for keras-preprocessing>=1.0.5 from https://files.pythonhosted.org/packages/79/4c/7c3275a01e12ef9368a892926ab932b33bb13d55794881e3573482b378a7/Keras_Preprocessing-1.1.2-py2.py3-none-any.whl.metadata
#   Downloading Keras_Preprocessing-1.1.2-py2.py3-none-any.whl.metadata (1.9 kB)
# Downloading Keras-2.2.4-py2.py3-none-any.whl (312 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 312.5/312.5 kB 4.3 MB/s eta 0:00:00 0:00:01
# Downloading Keras_Applications-1.0.8-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.7/50.7 kB 4.9 MB/s eta 0:00:00
# Downloading Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 4.2 MB/s eta 0:00:00
# Installing collected packages: keras-preprocessing, keras-applications, keras
#   Attempting uninstall: keras
#     Found existing installation: keras 3.9.0
#     Uninstalling keras-3.9.0:
#       Successfully uninstalled keras-3.9.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.18.0 requires keras>=3.5.0, but you have keras 2.2.4 which is incompatible.
# Successfully installed keras-2.2.4 keras-applications-1.0.8 keras-preprocessing-1.1.2
#
# [notice] A new release of pip is available: 23.2.1 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
# !pip install opencv-python scikit-image tensorflow
# Out:
# Requirement already satisfied: opencv-python in ./tf_env_py311/lib/python3.11/site-packages (4.11.0.86)
# Requirement already satisfied: scikit-image in ./tf_env_py311/lib/python3.11/site-packages (0.25.2)
# Requirement already satisfied: tensorflow in ./tf_env_py311/lib/python3.11/site-packages (2.18.0)
# Requirement already satisfied: numpy>=1.21.2 in ./tf_env_py311/lib/python3.11/site-packages (from opencv-python) (2.0.2)
# Requirement already satisfied: scipy>=1.11.4 in ./tf_env_py311/lib/python3.11/site-packages (from scikit-image) (1.15.2)
# Requirement already satisfied: networkx>=3.0 in ./tf_env_py311/lib/python3.11/site-packages (from scikit-image) (3.4.2)
# Requirement already satisfied: pillow>=10.1 in ./tf_env_py311/lib/python3.11/site-packages (from scikit-image) (11.1.0)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in ./tf_env_py311/lib/python3.11/site-packages (from scikit-image) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in ./tf_env_py311/lib/python3.11/site-packages (from scikit-image) (2025.2.18)
# Requirement already satisfied: packaging>=21 in ./tf_env_py311/lib/python3.11/site-packages (from scikit-image) (24.2)
# Requirement already satisfied: lazy-loader>=0.4 in ./tf_env_py311/lib/python3.11/site-packages (from scikit-image) (0.4)
# Requirement already satisfied: absl-py>=1.0.0 in ./tf_env_py311/lib/python3.11/site-packages (from tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in ./tf_env_py311/lib/python3.11/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in ./tf_env_py311/lib/python3.11/site-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in ./tf_env_py311/lib/python3.11/site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in ./tf_env_py311/lib/python3.11/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in ./tf_env_py311/lib/python3.11/site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in ./tf_env_py311/lib/python3.11/site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in ./tf_env_py311/lib/python3.11/site-packages (from tensorflow) (5.29.3)
# Requirement already satisfied: requests<3,>=2.21.0 in ./tf_env_py311/lib/python3.11/site-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in ./tf_env_py311/lib/python3.11/site-packages (from tensorflow) (65.5.0)
# Requirement already satisfied: six>=1.12.0 in ./tf_env_py311/lib/python3.11/site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in ./tf_env_py311/lib/python3.11/site-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in ./tf_env_py311/lib/python3.11/site-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in ./tf_env_py311/lib/python3.11/site-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in ./tf_env_py311/lib/python3.11/site-packages (from tensorflow) (1.70.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in ./tf_env_py311/lib/python3.11/site-packages (from tensorflow) (2.18.0)
# Collecting keras>=3.5.0 (from tensorflow)
#   Obtaining dependency information for keras>=3.5.0 from https://files.pythonhosted.org/packages/2b/98/e81c6b2cb522f0eadcc8e16f3cabaccd5462bff6cf52194acfed4a031d3f/keras-3.9.0-py3-none-any.whl.metadata
#   Using cached keras-3.9.0-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: h5py>=3.11.0 in ./tf_env_py311/lib/python3.11/site-packages (from tensorflow) (3.13.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in ./tf_env_py311/lib/python3.11/site-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in ./tf_env_py311/lib/python3.11/site-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in ./tf_env_py311/lib/python3.11/site-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in ./tf_env_py311/lib/python3.11/site-packages (from keras>=3.5.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in ./tf_env_py311/lib/python3.11/site-packages (from keras>=3.5.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in ./tf_env_py311/lib/python3.11/site-packages (from keras>=3.5.0->tensorflow) (0.14.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./tf_env_py311/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in ./tf_env_py311/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./tf_env_py311/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./tf_env_py311/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow) (2025.1.31)
# Requirement already satisfied: markdown>=2.6.8 in ./tf_env_py311/lib/python3.11/site-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in ./tf_env_py311/lib/python3.11/site-packages (from tensorboard<2.19,>=2.18->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in ./tf_env_py311/lib/python3.11/site-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in ./tf_env_py311/lib/python3.11/site-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in ./tf_env_py311/lib/python3.11/site-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in ./tf_env_py311/lib/python3.11/site-packages (from rich->keras>=3.5.0->tensorflow) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in ./tf_env_py311/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
# Using cached keras-3.9.0-py3-none-any.whl (1.3 MB)
# Installing collected packages: keras
#   Attempting uninstall: keras
#     Found existing installation: Keras 2.2.4
#     Uninstalling Keras-2.2.4:
#       Successfully uninstalled Keras-2.2.4
# Successfully installed keras-3.9.0
#
# [notice] A new release of pip is available: 23.2.1 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# # choose a different approach to use geoai-py

# %%
# !pip install geoai-py
# Out:
# Collecting geoai-py
#   Obtaining dependency information for geoai-py from https://files.pythonhosted.org/packages/19/75/18354dc9f89c410f9b3bd3b7fb4bb9e667fa174780faad4f17175b8a3c89/geoai_py-0.3.6-py2.py3-none-any.whl.metadata
#   Downloading geoai_py-0.3.6-py2.py3-none-any.whl.metadata (6.3 kB)
# Collecting albumentations (from geoai-py)
#   Obtaining dependency information for albumentations from https://files.pythonhosted.org/packages/97/d3/cf3aab593209d1be5e4bca54aeea297225708bd25f06426d6b8ec3630a76/albumentations-2.0.5-py3-none-any.whl.metadata
#   Downloading albumentations-2.0.5-py3-none-any.whl.metadata (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.7/41.7 kB 1.1 MB/s eta 0:00:00
# Collecting contextily (from geoai-py)
#   Obtaining dependency information for contextily from https://files.pythonhosted.org/packages/fb/46/07a029b73f9a5c7bbf9b538e6441c42014a448f335a1cc780616f2594bad/contextily-1.6.2-py3-none-any.whl.metadata
#   Downloading contextily-1.6.2-py3-none-any.whl.metadata (2.9 kB)
# Collecting geopandas (from geoai-py)
#   Obtaining dependency information for geopandas from https://files.pythonhosted.org/packages/c4/64/7d344cfcef5efddf9cf32f59af7f855828e9d74b5f862eddf5bfd9f25323/geopandas-1.0.1-py3-none-any.whl.metadata
#   Downloading geopandas-1.0.1-py3-none-any.whl.metadata (2.2 kB)
# Collecting huggingface_hub (from geoai-py)
#   Obtaining dependency information for huggingface_hub from https://files.pythonhosted.org/packages/13/5f/088ff08dc41808fcd99d9972b9bcfa7e3a35e30e8b0a3155b57938f1611c/huggingface_hub-0.29.2-py3-none-any.whl.metadata
#   Downloading huggingface_hub-0.29.2-py3-none-any.whl.metadata (13 kB)
# Collecting jupyter-server-proxy (from geoai-py)
#   Obtaining dependency information for jupyter-server-proxy from https://files.pythonhosted.org/packages/fd/c6/e4a1d9fdd22d40962befd82780a98b20b67ef9cafe87246e4955f44b8f09/jupyter_server_proxy-4.4.0-py3-none-any.whl.metadata
#   Downloading jupyter_server_proxy-4.4.0-py3-none-any.whl.metadata (8.7 kB)
# Collecting leafmap (from geoai-py)
#   Obtaining dependency information for leafmap from https://files.pythonhosted.org/packages/b3/80/5efeffec1661e8d21596e273c02dc3e8e5232c3184f2414f8703145ddd50/leafmap-0.42.13-py2.py3-none-any.whl.metadata
#   Downloading leafmap-0.42.13-py2.py3-none-any.whl.metadata (16 kB)
# Collecting localtileserver (from geoai-py)
#   Obtaining dependency information for localtileserver from https://files.pythonhosted.org/packages/e1/76/09a8df7973821af8e0b4708f442b746e29d19fbcc60f42c34fb437c9d3cb/localtileserver-0.10.6-py3-none-any.whl.metadata
#   Downloading localtileserver-0.10.6-py3-none-any.whl.metadata (5.2 kB)
# Collecting mapclassify (from geoai-py)
#   Obtaining dependency information for mapclassify from https://files.pythonhosted.org/packages/e7/e9/d7531a07454927788642373ae253ad6dd8714fec375a789031418ecebf2d/mapclassify-2.8.1-py3-none-any.whl.metadata
#   Downloading mapclassify-2.8.1-py3-none-any.whl.metadata (2.8 kB)
# Collecting overturemaps (from geoai-py)
#   Obtaining dependency information for overturemaps from https://files.pythonhosted.org/packages/9a/d7/8866a6e0a00a19667d09c2af9505fca8c4dcd134fa8e693c6e34c4d7d758/overturemaps-0.12.0-py3-none-any.whl.metadata
#   Downloading overturemaps-0.12.0-py3-none-any.whl.metadata (3.9 kB)
# Collecting planetary-computer (from geoai-py)
#   Obtaining dependency information for planetary-computer from https://files.pythonhosted.org/packages/4f/7a/3965a2b58d172e106c1064af19707d29f86a0142c28ff40185490a0a8cfe/planetary_computer-1.0.0-py3-none-any.whl.metadata
#   Downloading planetary_computer-1.0.0-py3-none-any.whl.metadata (7.4 kB)
# Collecting pystac-client (from geoai-py)
#   Obtaining dependency information for pystac-client from https://files.pythonhosted.org/packages/1d/7d/249eb4496b802f444cf0044e64b42ba57c8398d0952f63413c7f5bd6dfc9/pystac_client-0.8.6-py3-none-any.whl.metadata
#   Downloading pystac_client-0.8.6-py3-none-any.whl.metadata (3.0 kB)
# Collecting rasterio (from geoai-py)
#   Obtaining dependency information for rasterio from https://files.pythonhosted.org/packages/b3/59/ca86697161206233eea6353237b0c0f02f6f70434144db162f964a7e1b19/rasterio-1.4.3-cp311-cp311-macosx_14_0_arm64.whl.metadata
#   Downloading rasterio-1.4.3-cp311-cp311-macosx_14_0_arm64.whl.metadata (9.1 kB)
# Collecting rioxarray (from geoai-py)
#   Obtaining dependency information for rioxarray from https://files.pythonhosted.org/packages/fb/b0/2c74f302512fbd24d68fbba0ec6b650b33ef83e398daeb0a2bb1a4cd641c/rioxarray-0.18.2-py3-none-any.whl.metadata
#   Downloading rioxarray-0.18.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: scikit-image in ./tf_env_py311/lib/python3.11/site-packages (from geoai-py) (0.25.2)
# Collecting scikit-learn (from geoai-py)
#   Obtaining dependency information for scikit-learn from https://files.pythonhosted.org/packages/25/92/ee1d7a00bb6b8c55755d4984fd82608603a3cc59959245068ce32e7fb808/scikit_learn-1.6.1-cp311-cp311-macosx_12_0_arm64.whl.metadata
#   Downloading scikit_learn-1.6.1-cp311-cp311-macosx_12_0_arm64.whl.metadata (31 kB)
# Collecting torch (from geoai-py)
#   Obtaining dependency information for torch from https://files.pythonhosted.org/packages/0b/fa/f33a4148c6fb46ca2a3f8de39c24d473822d5774d652b66ed9b1214da5f7/torch-2.6.0-cp311-none-macosx_11_0_arm64.whl.metadata
#   Downloading torch-2.6.0-cp311-none-macosx_11_0_arm64.whl.metadata (28 kB)
# Collecting torchgeo (from geoai-py)
#   Obtaining dependency information for torchgeo from https://files.pythonhosted.org/packages/42/ef/8fd7f21b107ad291de1f40bab617c49f057b9d259bdbccb956f08e5c0f3b/torchgeo-0.6.2-py3-none-any.whl.metadata
#   Downloading torchgeo-0.6.2-py3-none-any.whl.metadata (19 kB)
# Collecting tqdm (from geoai-py)
#   Obtaining dependency information for tqdm from https://files.pythonhosted.org/packages/d0/30/dc54f88dd4a2b5dc8a0279bdd7270e735851848b762aeb1c1184ed1f6b14/tqdm-4.67.1-py3-none-any.whl.metadata
#   Downloading tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.7/57.7 kB 6.3 MB/s eta 0:00:00
# Collecting transformers (from geoai-py)
#   Obtaining dependency information for transformers from https://files.pythonhosted.org/packages/20/37/1f29af63e9c30156a3ed6ebc2754077016577c094f31de7b2631e5d379eb/transformers-4.49.0-py3-none-any.whl.metadata
#   Downloading transformers-4.49.0-py3-none-any.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 3.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.24.4 in ./tf_env_py311/lib/python3.11/site-packages (from albumentations->geoai-py) (2.0.2)
# Requirement already satisfied: scipy>=1.10.0 in ./tf_env_py311/lib/python3.11/site-packages (from albumentations->geoai-py) (1.15.2)
# Requirement already satisfied: PyYAML in ./tf_env_py311/lib/python3.11/site-packages (from albumentations->geoai-py) (6.0.2)
# Collecting pydantic>=2.9.2 (from albumentations->geoai-py)
#   Obtaining dependency information for pydantic>=2.9.2 from https://files.pythonhosted.org/packages/f4/3c/8cc1cc84deffa6e25d2d0c688ebb80635dfdbf1dbea3e30c541c8cf4d860/pydantic-2.10.6-py3-none-any.whl.metadata
#   Downloading pydantic-2.10.6-py3-none-any.whl.metadata (30 kB)
# Collecting albucore==0.0.23 (from albumentations->geoai-py)
#   Obtaining dependency information for albucore==0.0.23 from https://files.pythonhosted.org/packages/3d/de/4d9298befa6ae0f21230378f55100dca364816e3734028ca2766f2eca263/albucore-0.0.23-py3-none-any.whl.metadata
#   Downloading albucore-0.0.23-py3-none-any.whl.metadata (5.3 kB)
# Collecting opencv-python-headless>=4.9.0.80 (from albumentations->geoai-py)
#   Obtaining dependency information for opencv-python-headless>=4.9.0.80 from https://files.pythonhosted.org/packages/dc/53/2c50afa0b1e05ecdb4603818e85f7d174e683d874ef63a6abe3ac92220c8/opencv_python_headless-4.11.0.86-cp37-abi3-macosx_13_0_arm64.whl.metadata
#   Downloading opencv_python_headless-4.11.0.86-cp37-abi3-macosx_13_0_arm64.whl.metadata (20 kB)
# Collecting stringzilla>=3.10.4 (from albucore==0.0.23->albumentations->geoai-py)
#   Obtaining dependency information for stringzilla>=3.10.4 from https://files.pythonhosted.org/packages/1b/90/77e857203cd5d18523a81467f7c87fc102cefeafea0892fc98acb8e92ae7/stringzilla-3.12.3-cp311-cp311-macosx_11_0_arm64.whl.metadata
#   Downloading stringzilla-3.12.3-cp311-cp311-macosx_11_0_arm64.whl.metadata (80 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.3/80.3 kB 6.3 MB/s eta 0:00:00
# Collecting simsimd>=5.9.2 (from albucore==0.0.23->albumentations->geoai-py)
#   Obtaining dependency information for simsimd>=5.9.2 from https://files.pythonhosted.org/packages/5d/2b/9e7d42ac54bdb32d76953db3bc83eec29bd5d5c9a4069d380b18e200d6bd/simsimd-6.2.1-cp311-cp311-macosx_11_0_arm64.whl.metadata
#   Downloading simsimd-6.2.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.0/66.0 kB 3.7 MB/s eta 0:00:00
# Collecting geopy (from contextily->geoai-py)
#   Obtaining dependency information for geopy from https://files.pythonhosted.org/packages/e5/15/cf2a69ade4b194aa524ac75112d5caac37414b20a3a03e6865dfe0bd1539/geopy-2.4.1-py3-none-any.whl.metadata
#   Downloading geopy-2.4.1-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: matplotlib in ./tf_env_py311/lib/python3.11/site-packages (from contextily->geoai-py) (3.10.1)
# Collecting mercantile (from contextily->geoai-py)
#   Obtaining dependency information for mercantile from https://files.pythonhosted.org/packages/b2/d6/de0cc74f8d36976aeca0dd2e9cbf711882ff8e177495115fd82459afdc4d/mercantile-1.2.1-py3-none-any.whl.metadata
#   Downloading mercantile-1.2.1-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: pillow in ./tf_env_py311/lib/python3.11/site-packages (from contextily->geoai-py) (11.1.0)
# Requirement already satisfied: requests in ./tf_env_py311/lib/python3.11/site-packages (from contextily->geoai-py) (2.32.3)
# Collecting joblib (from contextily->geoai-py)
#   Obtaining dependency information for joblib from https://files.pythonhosted.org/packages/91/29/df4b9b42f2be0b623cbd5e2140cafcaa2bef0759a00b7b70104dcfe2fb51/joblib-1.4.2-py3-none-any.whl.metadata
#   Downloading joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting xyzservices (from contextily->geoai-py)
#   Obtaining dependency information for xyzservices from https://files.pythonhosted.org/packages/9a/6e/49408735dae940a0c1c225c6b908fd83bd6e3f5fae120f865754e72f78cb/xyzservices-2025.1.0-py3-none-any.whl.metadata
#   Downloading xyzservices-2025.1.0-py3-none-any.whl.metadata (4.3 kB)
# Collecting pyogrio>=0.7.2 (from geopandas->geoai-py)
#   Obtaining dependency information for pyogrio>=0.7.2 from https://files.pythonhosted.org/packages/8d/2c/c761e6adeb81bd4029a137b3240e7214a8c9aaf225883356196afd6ef9d8/pyogrio-0.10.0-cp311-cp311-macosx_12_0_arm64.whl.metadata
#   Downloading pyogrio-0.10.0-cp311-cp311-macosx_12_0_arm64.whl.metadata (5.5 kB)
# Requirement already satisfied: packaging in ./tf_env_py311/lib/python3.11/site-packages (from geopandas->geoai-py) (24.2)
# Collecting pandas>=1.4.0 (from geopandas->geoai-py)
#   Obtaining dependency information for pandas>=1.4.0 from https://files.pythonhosted.org/packages/52/11/9eac327a38834f162b8250aab32a6781339c69afe7574368fffe46387edf/pandas-2.2.3-cp311-cp311-macosx_11_0_arm64.whl.metadata
#   Downloading pandas-2.2.3-cp311-cp311-macosx_11_0_arm64.whl.metadata (89 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 5.2 MB/s eta 0:00:00
# Collecting pyproj>=3.3.0 (from geopandas->geoai-py)
#   Obtaining dependency information for pyproj>=3.3.0 from https://files.pythonhosted.org/packages/25/9d/cbaf82cfb290d1f1fa42feb9ba9464013bb3891e40c4199f8072112e4589/pyproj-3.7.1-cp311-cp311-macosx_14_0_arm64.whl.metadata
#   Downloading pyproj-3.7.1-cp311-cp311-macosx_14_0_arm64.whl.metadata (31 kB)
# Collecting shapely>=2.0.0 (from geopandas->geoai-py)
#   Obtaining dependency information for shapely>=2.0.0 from https://files.pythonhosted.org/packages/15/63/eef4f180f1b5859c70e7f91d2f2570643e5c61e7d7c40743d15f8c6cbc42/shapely-2.0.7-cp311-cp311-macosx_11_0_arm64.whl.metadata
#   Downloading shapely-2.0.7-cp311-cp311-macosx_11_0_arm64.whl.metadata (6.8 kB)
# Collecting filelock (from huggingface_hub->geoai-py)
#   Obtaining dependency information for filelock from https://files.pythonhosted.org/packages/89/ec/00d68c4ddfedfe64159999e5f8a98fb8442729a63e2077eb9dcd89623d27/filelock-3.17.0-py3-none-any.whl.metadata
#   Downloading filelock-3.17.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting fsspec>=2023.5.0 (from huggingface_hub->geoai-py)
#   Obtaining dependency information for fsspec>=2023.5.0 from https://files.pythonhosted.org/packages/56/53/eb690efa8513166adef3e0669afd31e95ffde69fb3c52ec2ac7223ed6018/fsspec-2025.3.0-py3-none-any.whl.metadata
#   Downloading fsspec-2025.3.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in ./tf_env_py311/lib/python3.11/site-packages (from huggingface_hub->geoai-py) (4.12.2)
# Collecting aiohttp (from jupyter-server-proxy->geoai-py)
#   Obtaining dependency information for aiohttp from https://files.pythonhosted.org/packages/d9/1c/56906111ac9d4dab4baab43c89d35d5de1dbb38085150257895005b08bef/aiohttp-3.11.13-cp311-cp311-macosx_11_0_arm64.whl.metadata
#   Downloading aiohttp-3.11.13-cp311-cp311-macosx_11_0_arm64.whl.metadata (7.7 kB)
# Requirement already satisfied: jupyter-server>=1.24.0 in ./tf_env_py311/lib/python3.11/site-packages (from jupyter-server-proxy->geoai-py) (2.15.0)
# Collecting simpervisor>=1.0.0 (from jupyter-server-proxy->geoai-py)
#   Obtaining dependency information for simpervisor>=1.0.0 from https://files.pythonhosted.org/packages/9e/65/be223a02df814a3dbd84d8a0c446d21d4860a4f23ec4d81aabea34e7e994/simpervisor-1.0.0-py3-none-any.whl.metadata
#   Downloading simpervisor-1.0.0-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: tornado>=6.1.0 in ./tf_env_py311/lib/python3.11/site-packages (from jupyter-server-proxy->geoai-py) (6.4.2)
# Requirement already satisfied: traitlets>=5.1.0 in ./tf_env_py311/lib/python3.11/site-packages (from jupyter-server-proxy->geoai-py) (5.14.3)
# Collecting anywidget (from leafmap->geoai-py)
#   Obtaining dependency information for anywidget from https://files.pythonhosted.org/packages/3a/cf/4f2797204895846d2a33a5f8e0cffcc3e23493c6daa10d500f9929da6644/anywidget-0.9.15-py3-none-any.whl.metadata
#   Downloading anywidget-0.9.15-py3-none-any.whl.metadata (8.9 kB)
# Collecting bqplot (from leafmap->geoai-py)
#   Obtaining dependency information for bqplot from https://files.pythonhosted.org/packages/92/bf/2ebe83bc691f5f7e68702caa38cca78d74f8a03b87eb962b62382d38490c/bqplot-0.12.44-py2.py3-none-any.whl.metadata
#   Downloading bqplot-0.12.44-py2.py3-none-any.whl.metadata (6.4 kB)
# Collecting colour (from leafmap->geoai-py)
#   Obtaining dependency information for colour from https://files.pythonhosted.org/packages/74/46/e81907704ab203206769dee1385dc77e1407576ff8f50a0681d0a6b541be/colour-0.1.5-py2.py3-none-any.whl.metadata
#   Downloading colour-0.1.5-py2.py3-none-any.whl.metadata (18 kB)
# Collecting duckdb (from leafmap->geoai-py)
#   Obtaining dependency information for duckdb from https://files.pythonhosted.org/packages/58/82/b119808dde71e42cc1fc77ac4a912e38c84eb47fa6ca4bc90652f99b7252/duckdb-1.2.1-cp311-cp311-macosx_12_0_arm64.whl.metadata
#   Downloading duckdb-1.2.1-cp311-cp311-macosx_12_0_arm64.whl.metadata (966 bytes)
# Collecting folium (from leafmap->geoai-py)
#   Obtaining dependency information for folium from https://files.pythonhosted.org/packages/81/4d/bcbee0676dc06f0b014a030cb928e158c96daafb872a01ddee7e60a8c998/folium-0.19.5-py2.py3-none-any.whl.metadata
#   Downloading folium-0.19.5-py2.py3-none-any.whl.metadata (4.1 kB)
# Collecting gdown (from leafmap->geoai-py)
#   Obtaining dependency information for gdown from https://files.pythonhosted.org/packages/54/70/e07c381e6488a77094f04c85c9caf1c8008cdc30778f7019bc52e5285ef0/gdown-5.2.0-py3-none-any.whl.metadata
#   Downloading gdown-5.2.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting geojson (from leafmap->geoai-py)
#   Obtaining dependency information for geojson from https://files.pythonhosted.org/packages/18/67/a7fa2d650602731c90e0a86279841b4586e14228199e8c09165ba4863e29/geojson-3.2.0-py3-none-any.whl.metadata
#   Downloading geojson-3.2.0-py3-none-any.whl.metadata (16 kB)
# Collecting ipyevents (from leafmap->geoai-py)
#   Obtaining dependency information for ipyevents from https://files.pythonhosted.org/packages/af/49/5692d363a82838282f5c33a787922f07115d7ba4b452391e51db95c9d247/ipyevents-2.0.2-py3-none-any.whl.metadata
#   Downloading ipyevents-2.0.2-py3-none-any.whl.metadata (2.9 kB)
# Collecting ipyfilechooser (from leafmap->geoai-py)
#   Obtaining dependency information for ipyfilechooser from https://files.pythonhosted.org/packages/00/60/249e3444fcd9c833704741769981cd02fe2c7ce94126b1394e7a3b26e543/ipyfilechooser-0.6.0-py3-none-any.whl.metadata
#   Downloading ipyfilechooser-0.6.0-py3-none-any.whl.metadata (6.4 kB)
# Collecting ipyleaflet (from leafmap->geoai-py)
#   Obtaining dependency information for ipyleaflet from https://files.pythonhosted.org/packages/56/6f/00d60e93a316a178ae04457ceea5bcbb4e2d7e7e469882ac59ec4cccfb8c/ipyleaflet-0.19.2-py3-none-any.whl.metadata
#   Downloading ipyleaflet-0.19.2-py3-none-any.whl.metadata (5.3 kB)
# Collecting ipyvuetify (from leafmap->geoai-py)
#   Obtaining dependency information for ipyvuetify from https://files.pythonhosted.org/packages/59/a9/9a156fd53c9939f753a6858a0ec3a28c8264f383a2dd7ace5debd39182c4/ipyvuetify-1.11.1-py2.py3-none-any.whl.metadata
#   Downloading ipyvuetify-1.11.1-py2.py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: ipywidgets in ./tf_env_py311/lib/python3.11/site-packages (from leafmap->geoai-py) (8.1.5)
# Collecting plotly (from leafmap->geoai-py)
#   Obtaining dependency information for plotly from https://files.pythonhosted.org/packages/0e/77/a946f38b57fb88e736c71fbdd737a1aebd27b532bda0779c137f357cf5fc/plotly-6.0.0-py3-none-any.whl.metadata
#   Downloading plotly-6.0.0-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: psutil in ./tf_env_py311/lib/python3.11/site-packages (from leafmap->geoai-py) (7.0.0)
# Collecting pyshp (from leafmap->geoai-py)
#   Obtaining dependency information for pyshp from https://files.pythonhosted.org/packages/98/2f/68116db5b36b895c0450e3072b8cb6c2fac0359279b182ea97014d3c8ac0/pyshp-2.3.1-py2.py3-none-any.whl.metadata
#   Downloading pyshp-2.3.1-py2.py3-none-any.whl.metadata (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.0/56.0 kB 3.9 MB/s eta 0:00:00
# Collecting python-box (from leafmap->geoai-py)
#   Obtaining dependency information for python-box from https://files.pythonhosted.org/packages/1e/3f/133619c00d8a9d4f86efd8626c0e4ec356c8b8dabac66da18dac5cfaf70c/python_box-7.3.2-cp311-cp311-macosx_10_9_universal2.whl.metadata
#   Downloading python_box-7.3.2-cp311-cp311-macosx_10_9_universal2.whl.metadata (8.0 kB)
# Collecting scooby (from leafmap->geoai-py)
#   Obtaining dependency information for scooby from https://files.pythonhosted.org/packages/2f/4b/ea1c1c4ecaa97baf8001568d502eaff1bbc3d5c1b48cce3f3fd5a77b8f52/scooby-0.10.0-py3-none-any.whl.metadata
#   Downloading scooby-0.10.0-py3-none-any.whl.metadata (15 kB)
# Collecting whiteboxgui (from leafmap->geoai-py)
#   Obtaining dependency information for whiteboxgui from https://files.pythonhosted.org/packages/bf/f3/320f1f5b67fceb23a5f3556d5d728d2fbcaaca0ce60cdb50a8715e0f8c19/whiteboxgui-2.3.0-py2.py3-none-any.whl.metadata
#   Downloading whiteboxgui-2.3.0-py2.py3-none-any.whl.metadata (5.7 kB)
# Collecting click (from localtileserver->geoai-py)
#   Obtaining dependency information for click from https://files.pythonhosted.org/packages/7e/d4/7ebdbd03970677812aac39c869717059dbb71a4cfc033ca6e5221787892c/click-8.1.8-py3-none-any.whl.metadata
#   Downloading click-8.1.8-py3-none-any.whl.metadata (2.3 kB)
# Collecting flask<4,>=2.0.0 (from localtileserver->geoai-py)
#   Obtaining dependency information for flask<4,>=2.0.0 from https://files.pythonhosted.org/packages/af/47/93213ee66ef8fae3b93b3e29206f6b251e65c97bd91d8e1c5596ef15af0a/flask-3.1.0-py3-none-any.whl.metadata
#   Downloading flask-3.1.0-py3-none-any.whl.metadata (2.7 kB)
# Collecting Flask-Caching (from localtileserver->geoai-py)
#   Obtaining dependency information for Flask-Caching from https://files.pythonhosted.org/packages/00/bb/82daa5e2fcecafadcc8659ce5779679d0641666f9252a4d5a2ae987b0506/Flask_Caching-2.3.1-py3-none-any.whl.metadata
#   Downloading Flask_Caching-2.3.1-py3-none-any.whl.metadata (2.2 kB)
# Collecting flask-cors (from localtileserver->geoai-py)
#   Obtaining dependency information for flask-cors from https://files.pythonhosted.org/packages/85/61/4aea5fb55be1b6f95e604627dc6c50c47d693e39cab2ac086ee0155a0abd/flask_cors-5.0.1-py3-none-any.whl.metadata
#   Downloading flask_cors-5.0.1-py3-none-any.whl.metadata (961 bytes)
# Collecting flask-restx>=1.3.0 (from localtileserver->geoai-py)
#   Obtaining dependency information for flask-restx>=1.3.0 from https://files.pythonhosted.org/packages/a5/bf/1907369f2a7ee614dde5152ff8f811159d357e77962aa3f8c2e937f63731/flask_restx-1.3.0-py2.py3-none-any.whl.metadata
#   Downloading flask_restx-1.3.0-py2.py3-none-any.whl.metadata (9.3 kB)
# Collecting rio-tiler (from localtileserver->geoai-py)
#   Obtaining dependency information for rio-tiler from https://files.pythonhosted.org/packages/d7/96/694c0227822d96d3b11378b50eaeae61292540c8aac91e72b8ce553f28d5/rio_tiler-7.5.0-py3-none-any.whl.metadata
#   Downloading rio_tiler-7.5.0-py3-none-any.whl.metadata (12 kB)
# Collecting rio-cogeo (from localtileserver->geoai-py)
#   Obtaining dependency information for rio-cogeo from https://files.pythonhosted.org/packages/25/69/d16afb79dcd2ab0b679713ed0d04acd2c0dd2345b7d545823f5c6f2f44b1/rio_cogeo-5.4.1-py3-none-any.whl.metadata
#   Downloading rio_cogeo-5.4.1-py3-none-any.whl.metadata (4.7 kB)
# Collecting server-thread (from localtileserver->geoai-py)
#   Obtaining dependency information for server-thread from https://files.pythonhosted.org/packages/bf/85/3ffc300dc13ea00a4fe063338ee9352a322a8932338ed45a18473d1a4806/server_thread-0.3.0-py3-none-any.whl.metadata
#   Downloading server_thread-0.3.0-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: werkzeug in ./tf_env_py311/lib/python3.11/site-packages (from localtileserver->geoai-py) (3.1.3)
# Requirement already satisfied: networkx>=2.7 in ./tf_env_py311/lib/python3.11/site-packages (from mapclassify->geoai-py) (3.4.2)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn->geoai-py)
#   Obtaining dependency information for threadpoolctl>=3.1.0 from https://files.pythonhosted.org/packages/4b/2c/ffbf7a134b9ab11a67b0cf0726453cedd9c5043a4fe7a35d1cefa9a1bcfb/threadpoolctl-3.5.0-py3-none-any.whl.metadata
#   Downloading threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# Collecting pyarrow>=15.0.2 (from overturemaps->geoai-py)
#   Obtaining dependency information for pyarrow>=15.0.2 from https://files.pythonhosted.org/packages/a0/55/f1a8d838ec07fe3ca53edbe76f782df7b9aafd4417080eebf0b42aab0c52/pyarrow-19.0.1-cp311-cp311-macosx_12_0_arm64.whl.metadata
#   Downloading pyarrow-19.0.1-cp311-cp311-macosx_12_0_arm64.whl.metadata (3.3 kB)
# Collecting pystac>=1.0.0 (from planetary-computer->geoai-py)
#   Obtaining dependency information for pystac>=1.0.0 from https://files.pythonhosted.org/packages/08/94/6f93e55886cae4076dfe1c5c0a768963f6faca34d7cd27a2ee6800e29387/pystac-1.12.2-py3-none-any.whl.metadata
#   Downloading pystac-1.12.2-py3-none-any.whl.metadata (4.6 kB)
# Collecting pytz>=2020.5 (from planetary-computer->geoai-py)
#   Obtaining dependency information for pytz>=2020.5 from https://files.pythonhosted.org/packages/eb/38/ac33370d784287baa1c3d538978b5e2ea064d4c1b93ffbd12826c190dd10/pytz-2025.1-py2.py3-none-any.whl.metadata
#   Downloading pytz-2025.1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting python-dotenv (from planetary-computer->geoai-py)
#   Obtaining dependency information for python-dotenv from https://files.pythonhosted.org/packages/6a/3e/b68c118422ec867fa7ab88444e1274aa40681c606d59ac27de5a5588f082/python_dotenv-1.0.1-py3-none-any.whl.metadata
#   Using cached python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./tf_env_py311/lib/python3.11/site-packages (from pystac-client->geoai-py) (2.9.0.post0)
# Collecting affine (from rasterio->geoai-py)
#   Obtaining dependency information for affine from https://files.pythonhosted.org/packages/0b/f7/85273299ab57117850cc0a936c64151171fac4da49bc6fba0dad984a7c5f/affine-2.4.0-py3-none-any.whl.metadata
#   Downloading affine-2.4.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: attrs in ./tf_env_py311/lib/python3.11/site-packages (from rasterio->geoai-py) (25.1.0)
# Requirement already satisfied: certifi in ./tf_env_py311/lib/python3.11/site-packages (from rasterio->geoai-py) (2025.1.31)
# Collecting cligj>=0.5 (from rasterio->geoai-py)
#   Obtaining dependency information for cligj>=0.5 from https://files.pythonhosted.org/packages/73/86/43fa9f15c5b9fb6e82620428827cd3c284aa933431405d1bcf5231ae3d3e/cligj-0.7.2-py3-none-any.whl.metadata
#   Downloading cligj-0.7.2-py3-none-any.whl.metadata (5.0 kB)
# Collecting click-plugins (from rasterio->geoai-py)
#   Obtaining dependency information for click-plugins from https://files.pythonhosted.org/packages/e9/da/824b92d9942f4e472702488857914bdd50f73021efea15b4cad9aca8ecef/click_plugins-1.1.1-py2.py3-none-any.whl.metadata
#   Downloading click_plugins-1.1.1-py2.py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: pyparsing in ./tf_env_py311/lib/python3.11/site-packages (from rasterio->geoai-py) (3.2.1)
# Collecting xarray>=2024.7.0 (from rioxarray->geoai-py)
#   Obtaining dependency information for xarray>=2024.7.0 from https://files.pythonhosted.org/packages/05/79/4e19100342fe13d69fd6e77b343e2269924fec681258e2ea21b55576aad2/xarray-2025.1.2-py3-none-any.whl.metadata
#   Downloading xarray-2025.1.2-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in ./tf_env_py311/lib/python3.11/site-packages (from scikit-image->geoai-py) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in ./tf_env_py311/lib/python3.11/site-packages (from scikit-image->geoai-py) (2025.2.18)
# Requirement already satisfied: lazy-loader>=0.4 in ./tf_env_py311/lib/python3.11/site-packages (from scikit-image->geoai-py) (0.4)
# Requirement already satisfied: jinja2 in ./tf_env_py311/lib/python3.11/site-packages (from torch->geoai-py) (3.1.5)
# Collecting sympy==1.13.1 (from torch->geoai-py)
#   Obtaining dependency information for sympy==1.13.1 from https://files.pythonhosted.org/packages/b2/fe/81695a1aa331a842b582453b605175f419fe8540355886031328089d840a/sympy-1.13.1-py3-none-any.whl.metadata
#   Downloading sympy-1.13.1-py3-none-any.whl.metadata (12 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy==1.13.1->torch->geoai-py)
#   Obtaining dependency information for mpmath<1.4,>=1.1.0 from https://files.pythonhosted.org/packages/43/e3/7d92a15f894aa0c9c4b49b8ee9ac9850d6e63b03c9c32c0367a13ae62209/mpmath-1.3.0-py3-none-any.whl.metadata
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting einops>=0.3 (from torchgeo->geoai-py)
#   Obtaining dependency information for einops>=0.3 from https://files.pythonhosted.org/packages/87/62/9773de14fe6c45c23649e98b83231fffd7b9892b6cf863251dc2afa73643/einops-0.8.1-py3-none-any.whl.metadata
#   Downloading einops-0.8.1-py3-none-any.whl.metadata (13 kB)
# Collecting fiona>=1.8.21 (from torchgeo->geoai-py)
#   Obtaining dependency information for fiona>=1.8.21 from https://files.pythonhosted.org/packages/65/0c/e8070b15c8303f60bd4444a120842597ccd6ed550548948e2e36cffbaa93/fiona-1.10.1-cp311-cp311-macosx_11_0_arm64.whl.metadata
#   Downloading fiona-1.10.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.6/56.6 kB 2.3 MB/s eta 0:00:00
# Collecting kornia>=0.7.3 (from torchgeo->geoai-py)
#   Obtaining dependency information for kornia>=0.7.3 from https://files.pythonhosted.org/packages/f2/33/7721a4f69dd5f020c30de456d7b948fea8d3897d9f29a51f7538948ee7e2/kornia-0.8.0-py2.py3-none-any.whl.metadata
#   Downloading kornia-0.8.0-py2.py3-none-any.whl.metadata (17 kB)
# Collecting lightly!=1.4.26,>=1.4.5 (from torchgeo->geoai-py)
#   Obtaining dependency information for lightly!=1.4.26,>=1.4.5 from https://files.pythonhosted.org/packages/95/01/377210fb1d1bcbcac5cd00a8f1bf55228346a8f2e24c41b30b9c130b8c83/lightly-1.5.19-py3-none-any.whl.metadata
#   Downloading lightly-1.5.19-py3-none-any.whl.metadata (36 kB)
# Collecting lightning[pytorch-extra]!=2.3.*,>=2 (from torchgeo->geoai-py)
#   Obtaining dependency information for lightning[pytorch-extra]!=2.3.*,>=2 from https://files.pythonhosted.org/packages/d4/54/2de887e964a561776ac49c5e715ca8a56138ea7e2b95325e0a79aa46a070/lightning-2.5.0.post0-py3-none-any.whl.metadata
#   Downloading lightning-2.5.0.post0-py3-none-any.whl.metadata (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.4/40.4 kB 3.4 MB/s eta 0:00:00
# Collecting rtree>=1 (from torchgeo->geoai-py)
#   Obtaining dependency information for rtree>=1 from https://files.pythonhosted.org/packages/20/29/045e700d2135e9a67896086c831fde80fd4105971b443d5727a4093fcbf1/rtree-1.4.0-py3-none-macosx_11_0_arm64.whl.metadata
#   Downloading rtree-1.4.0-py3-none-macosx_11_0_arm64.whl.metadata (2.1 kB)
# Collecting segmentation-models-pytorch>=0.2 (from torchgeo->geoai-py)
#   Obtaining dependency information for segmentation-models-pytorch>=0.2 from https://files.pythonhosted.org/packages/1e/dd/02779033f660b670c6050a35b4f9eb9e536fa6c719af4a4f59f095a2c70f/segmentation_models_pytorch-0.4.0-py3-none-any.whl.metadata
#   Downloading segmentation_models_pytorch-0.4.0-py3-none-any.whl.metadata (32 kB)
# Collecting timm>=0.4.12 (from torchgeo->geoai-py)
#   Obtaining dependency information for timm>=0.4.12 from https://files.pythonhosted.org/packages/6c/d0/179abca8b984b3deefd996f362b612c39da73b60f685921e6cd58b6125b4/timm-1.0.15-py3-none-any.whl.metadata
#   Downloading timm-1.0.15-py3-none-any.whl.metadata (52 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.0/52.0 kB 3.9 MB/s eta 0:00:00
# Collecting torchmetrics>=0.10 (from torchgeo->geoai-py)
#   Obtaining dependency information for torchmetrics>=0.10 from https://files.pythonhosted.org/packages/63/c3/4e87b5f6bbd9600e3fab42267f242e8d5c3a04749afd1b6735231a9511e9/torchmetrics-1.6.2-py3-none-any.whl.metadata
#   Downloading torchmetrics-1.6.2-py3-none-any.whl.metadata (20 kB)
# Collecting torchvision>=0.14 (from torchgeo->geoai-py)
#   Obtaining dependency information for torchvision>=0.14 from https://files.pythonhosted.org/packages/29/88/00c69db213ee2443ada8886ec60789b227e06bb869d85ee324578221a7f7/torchvision-0.21.0-cp311-cp311-macosx_11_0_arm64.whl.metadata
#   Downloading torchvision-0.21.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (6.1 kB)
# Collecting regex!=2019.12.17 (from transformers->geoai-py)
#   Obtaining dependency information for regex!=2019.12.17 from https://files.pythonhosted.org/packages/c5/1b/f0e4d13e6adf866ce9b069e191f303a30ab1277e037037a365c3aad5cc9c/regex-2024.11.6-cp311-cp311-macosx_11_0_arm64.whl.metadata
#   Downloading regex-2024.11.6-cp311-cp311-macosx_11_0_arm64.whl.metadata (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.5/40.5 kB 3.3 MB/s eta 0:00:00
# Collecting tokenizers<0.22,>=0.21 (from transformers->geoai-py)
#   Obtaining dependency information for tokenizers<0.22,>=0.21 from https://files.pythonhosted.org/packages/22/7a/88e58bb297c22633ed1c9d16029316e5b5ac5ee44012164c2edede599a5e/tokenizers-0.21.0-cp39-abi3-macosx_11_0_arm64.whl.metadata
#   Downloading tokenizers-0.21.0-cp39-abi3-macosx_11_0_arm64.whl.metadata (6.7 kB)
# Collecting safetensors>=0.4.1 (from transformers->geoai-py)
#   Obtaining dependency information for safetensors>=0.4.1 from https://files.pythonhosted.org/packages/b8/3b/11f1b4a2f5d2ab7da34ecc062b0bc301f2be024d110a6466726bec8c055c/safetensors-0.5.3-cp38-abi3-macosx_11_0_arm64.whl.metadata
#   Downloading safetensors-0.5.3-cp38-abi3-macosx_11_0_arm64.whl.metadata (3.8 kB)
# Collecting itsdangerous>=2.2 (from flask<4,>=2.0.0->localtileserver->geoai-py)
#   Obtaining dependency information for itsdangerous>=2.2 from https://files.pythonhosted.org/packages/04/96/92447566d16df59b2a776c0fb82dbc4d9e07cd95062562af01e408583fc4/itsdangerous-2.2.0-py3-none-any.whl.metadata
#   Downloading itsdangerous-2.2.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting blinker>=1.9 (from flask<4,>=2.0.0->localtileserver->geoai-py)
#   Obtaining dependency information for blinker>=1.9 from https://files.pythonhosted.org/packages/10/cb/f2ad4230dc2eb1a74edf38f1a38b9b52277f75bef262d8908e60d957e13c/blinker-1.9.0-py3-none-any.whl.metadata
#   Downloading blinker-1.9.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting aniso8601>=0.82 (from flask-restx>=1.3.0->localtileserver->geoai-py)
#   Obtaining dependency information for aniso8601>=0.82 from https://files.pythonhosted.org/packages/72/bf/d5cde2cb7cdc2cb1770d974418d169a79c3187bd962cb752b9fd617848ca/aniso8601-10.0.0-py2.py3-none-any.whl.metadata
#   Downloading aniso8601-10.0.0-py2.py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: jsonschema in ./tf_env_py311/lib/python3.11/site-packages (from flask-restx>=1.3.0->localtileserver->geoai-py) (4.23.0)
# Collecting importlib-resources (from flask-restx>=1.3.0->localtileserver->geoai-py)
#   Obtaining dependency information for importlib-resources from https://files.pythonhosted.org/packages/a4/ed/1f1afb2e9e7f38a545d628f864d562a5ae64fe6f7a10e28ffb9b185b4e89/importlib_resources-6.5.2-py3-none-any.whl.metadata
#   Downloading importlib_resources-6.5.2-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in ./tf_env_py311/lib/python3.11/site-packages (from jinja2->torch->geoai-py) (3.0.2)
# Requirement already satisfied: anyio>=3.1.0 in ./tf_env_py311/lib/python3.11/site-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py) (4.8.0)
# Requirement already satisfied: argon2-cffi>=21.1 in ./tf_env_py311/lib/python3.11/site-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py) (23.1.0)
# Requirement already satisfied: jupyter-client>=7.4.4 in ./tf_env_py311/lib/python3.11/site-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in ./tf_env_py311/lib/python3.11/site-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py) (5.7.2)
# Requirement already satisfied: jupyter-events>=0.11.0 in ./tf_env_py311/lib/python3.11/site-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in ./tf_env_py311/lib/python3.11/site-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py) (0.5.3)
# Requirement already satisfied: nbconvert>=6.4.4 in ./tf_env_py311/lib/python3.11/site-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py) (7.16.6)
# Requirement already satisfied: nbformat>=5.3.0 in ./tf_env_py311/lib/python3.11/site-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in ./tf_env_py311/lib/python3.11/site-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in ./tf_env_py311/lib/python3.11/site-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py) (0.21.1)
# Requirement already satisfied: pyzmq>=24 in ./tf_env_py311/lib/python3.11/site-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py) (26.2.1)
# Requirement already satisfied: send2trash>=1.8.2 in ./tf_env_py311/lib/python3.11/site-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in ./tf_env_py311/lib/python3.11/site-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in ./tf_env_py311/lib/python3.11/site-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py) (1.8.0)
# Collecting kornia_rs>=0.1.0 (from kornia>=0.7.3->torchgeo->geoai-py)
#   Obtaining dependency information for kornia_rs>=0.1.0 from https://files.pythonhosted.org/packages/86/6b/f8b257bf88b0e167e9732c9190746a3a71fe4b9b6c8831529664285dedc4/kornia_rs-0.1.8-cp311-cp311-macosx_11_0_arm64.whl.metadata
#   Downloading kornia_rs-0.1.8-cp311-cp311-macosx_11_0_arm64.whl.metadata (10 kB)
# Collecting hydra-core>=1.0.0 (from lightly!=1.4.26,>=1.4.5->torchgeo->geoai-py)
#   Obtaining dependency information for hydra-core>=1.0.0 from https://files.pythonhosted.org/packages/c6/50/e0edd38dcd63fb26a8547f13d28f7a008bc4a3fd4eb4ff030673f22ad41a/hydra_core-1.3.2-py3-none-any.whl.metadata
#   Downloading hydra_core-1.3.2-py3-none-any.whl.metadata (5.5 kB)
# Collecting lightly_utils~=0.0.0 (from lightly!=1.4.26,>=1.4.5->torchgeo->geoai-py)
#   Obtaining dependency information for lightly_utils~=0.0.0 from https://files.pythonhosted.org/packages/62/11/ff55b3f54440e604a589ae1fe6950bc1bf49b5aca1842bf4b3ab0b6f65cd/lightly_utils-0.0.2-py3-none-any.whl.metadata
#   Downloading lightly_utils-0.0.2-py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.10 in ./tf_env_py311/lib/python3.11/site-packages (from lightly!=1.4.26,>=1.4.5->torchgeo->geoai-py) (1.17.0)
# Collecting pytorch_lightning>=1.0.4 (from lightly!=1.4.26,>=1.4.5->torchgeo->geoai-py)
#   Obtaining dependency information for pytorch_lightning>=1.0.4 from https://files.pythonhosted.org/packages/02/df/0c7e4582b74264fe2179e78fcdeb9313f680d40ffe1dd4b078da5a2cbf82/pytorch_lightning-2.5.0.post0-py3-none-any.whl.metadata
#   Downloading pytorch_lightning-2.5.0.post0-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: urllib3>=1.25.3 in ./tf_env_py311/lib/python3.11/site-packages (from lightly!=1.4.26,>=1.4.5->torchgeo->geoai-py) (2.3.0)
# Collecting aenum>=3.1.11 (from lightly!=1.4.26,>=1.4.5->torchgeo->geoai-py)
#   Obtaining dependency information for aenum>=3.1.11 from https://files.pythonhosted.org/packages/d0/fa/ca0c66b388624ba9dbbf35aab3a9f326bfdf5e56a7237fe8f1b600da6864/aenum-3.1.15-py3-none-any.whl.metadata
#   Downloading aenum-3.1.15-py3-none-any.whl.metadata (3.7 kB)
# Collecting lightning-utilities<2.0,>=0.10.0 (from lightning[pytorch-extra]!=2.3.*,>=2->torchgeo->geoai-py)
#   Obtaining dependency information for lightning-utilities<2.0,>=0.10.0 from https://files.pythonhosted.org/packages/44/ef/b48a8bba9d0ac84141049c71ad32adcfed030d10ac2963c7c3c8c0e66091/lightning_utilities-0.14.0-py3-none-any.whl.metadata
#   Downloading lightning_utilities-0.14.0-py3-none-any.whl.metadata (5.6 kB)
# Collecting jsonargparse[signatures]<5.0,>=4.27.7 (from lightning[pytorch-extra]!=2.3.*,>=2->torchgeo->geoai-py)
#   Obtaining dependency information for jsonargparse[signatures]<5.0,>=4.27.7 from https://files.pythonhosted.org/packages/3c/c4/112d8a91488b19c231711c0d9bfca044890003093b54cdfd144ca0e76ac8/jsonargparse-4.37.0-py3-none-any.whl.metadata
#   Downloading jsonargparse-4.37.0-py3-none-any.whl.metadata (12 kB)
# Collecting omegaconf<3.0,>=2.2.3 (from lightning[pytorch-extra]!=2.3.*,>=2->torchgeo->geoai-py)
#   Obtaining dependency information for omegaconf<3.0,>=2.2.3 from https://files.pythonhosted.org/packages/e3/94/1843518e420fa3ed6919835845df698c7e27e183cb997394e4a670973a65/omegaconf-2.3.0-py3-none-any.whl.metadata
#   Downloading omegaconf-2.3.0-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: rich<14.0,>=12.3.0 in ./tf_env_py311/lib/python3.11/site-packages (from lightning[pytorch-extra]!=2.3.*,>=2->torchgeo->geoai-py) (13.9.4)
# Collecting tensorboardX<3.0,>=2.2 (from lightning[pytorch-extra]!=2.3.*,>=2->torchgeo->geoai-py)
#   Obtaining dependency information for tensorboardX<3.0,>=2.2 from https://files.pythonhosted.org/packages/44/71/f3e7c9b2ab67e28c572ab4e9d5fa3499e0d252650f96d8a3a03e26677f53/tensorboardX-2.6.2.2-py2.py3-none-any.whl.metadata
#   Downloading tensorboardX-2.6.2.2-py2.py3-none-any.whl.metadata (5.8 kB)
# Collecting bitsandbytes<1.0,>=0.42.0 (from lightning[pytorch-extra]!=2.3.*,>=2->torchgeo->geoai-py)
#   Obtaining dependency information for bitsandbytes<1.0,>=0.42.0 from https://files.pythonhosted.org/packages/9b/63/489ef9cd7a33c1f08f1b2be51d1b511883c5e34591aaa9873b30021cd679/bitsandbytes-0.42.0-py3-none-any.whl.metadata
#   Downloading bitsandbytes-0.42.0-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: contourpy>=1.0.1 in ./tf_env_py311/lib/python3.11/site-packages (from matplotlib->contextily->geoai-py) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in ./tf_env_py311/lib/python3.11/site-packages (from matplotlib->contextily->geoai-py) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./tf_env_py311/lib/python3.11/site-packages (from matplotlib->contextily->geoai-py) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./tf_env_py311/lib/python3.11/site-packages (from matplotlib->contextily->geoai-py) (1.4.8)
# Collecting tzdata>=2022.7 (from pandas>=1.4.0->geopandas->geoai-py)
#   Obtaining dependency information for tzdata>=2022.7 from https://files.pythonhosted.org/packages/0f/dd/84f10e23edd882c6f968c21c2434fe67bd4a528967067515feca9e611e5e/tzdata-2025.1-py2.py3-none-any.whl.metadata
#   Downloading tzdata-2025.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting annotated-types>=0.6.0 (from pydantic>=2.9.2->albumentations->geoai-py)
#   Obtaining dependency information for annotated-types>=0.6.0 from https://files.pythonhosted.org/packages/78/b6/6307fbef88d9b5ee7421e68d78a9f162e0da4900bc5f5793f6d3d0e34fb8/annotated_types-0.7.0-py3-none-any.whl.metadata
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.27.2 (from pydantic>=2.9.2->albumentations->geoai-py)
#   Obtaining dependency information for pydantic-core==2.27.2 from https://files.pythonhosted.org/packages/9e/e3/71fe85af2021f3f386da42d291412e5baf6ce7716bd7101ea49c810eda90/pydantic_core-2.27.2-cp311-cp311-macosx_11_0_arm64.whl.metadata
#   Downloading pydantic_core-2.27.2-cp311-cp311-macosx_11_0_arm64.whl.metadata (6.6 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./tf_env_py311/lib/python3.11/site-packages (from requests->contextily->geoai-py) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in ./tf_env_py311/lib/python3.11/site-packages (from requests->contextily->geoai-py) (3.10)
# Collecting efficientnet-pytorch>=0.6.1 (from segmentation-models-pytorch>=0.2->torchgeo->geoai-py)
#   Downloading efficientnet_pytorch-0.7.1.tar.gz (21 kB)
#   Preparing metadata (setup.py) ... done
# Collecting pretrainedmodels>=0.7.1 (from segmentation-models-pytorch>=0.2->torchgeo->geoai-py)
#   Downloading pretrainedmodels-0.7.4.tar.gz (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 4.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting aiohappyeyeballs>=2.3.0 (from aiohttp->jupyter-server-proxy->geoai-py)
#   Obtaining dependency information for aiohappyeyeballs>=2.3.0 from https://files.pythonhosted.org/packages/1b/9a/e4886864ce06e1579bd428208127fbdc0d62049c751e4e9e3b509c0059dc/aiohappyeyeballs-2.5.0-py3-none-any.whl.metadata
#   Downloading aiohappyeyeballs-2.5.0-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp->jupyter-server-proxy->geoai-py)
#   Obtaining dependency information for aiosignal>=1.1.2 from https://files.pythonhosted.org/packages/ec/6a/bc7e17a3e87a2985d3e8f4da4cd0f481060eb78fb08596c42be62c90a4d9/aiosignal-1.3.2-py2.py3-none-any.whl.metadata
#   Downloading aiosignal-1.3.2-py2.py3-none-any.whl.metadata (3.8 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp->jupyter-server-proxy->geoai-py)
#   Obtaining dependency information for frozenlist>=1.1.1 from https://files.pythonhosted.org/packages/2c/31/ab01375682f14f7613a1ade30149f684c84f9b8823a4391ed950c8285656/frozenlist-1.5.0-cp311-cp311-macosx_11_0_arm64.whl.metadata
#   Downloading frozenlist-1.5.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (13 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp->jupyter-server-proxy->geoai-py)
#   Obtaining dependency information for multidict<7.0,>=4.5 from https://files.pythonhosted.org/packages/70/0f/6dc70ddf5d442702ed74f298d69977f904960b82368532c88e854b79f72b/multidict-6.1.0-cp311-cp311-macosx_11_0_arm64.whl.metadata
#   Downloading multidict-6.1.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (5.0 kB)
# Collecting propcache>=0.2.0 (from aiohttp->jupyter-server-proxy->geoai-py)
#   Obtaining dependency information for propcache>=0.2.0 from https://files.pythonhosted.org/packages/f6/91/ee5b6aa7aa31754fefcf0c5180e09223cac380ef195c4ddc8c266eb641ea/propcache-0.3.0-cp311-cp311-macosx_11_0_arm64.whl.metadata
#   Downloading propcache-0.3.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (10 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp->jupyter-server-proxy->geoai-py)
#   Obtaining dependency information for yarl<2.0,>=1.17.0 from https://files.pythonhosted.org/packages/5a/a1/205ab51e148fdcedad189ca8dd587794c6f119882437d04c33c01a75dece/yarl-1.18.3-cp311-cp311-macosx_11_0_arm64.whl.metadata
#   Downloading yarl-1.18.3-cp311-cp311-macosx_11_0_arm64.whl.metadata (69 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.2/69.2 kB 4.9 MB/s eta 0:00:00
# Collecting psygnal>=0.8.1 (from anywidget->leafmap->geoai-py)
#   Obtaining dependency information for psygnal>=0.8.1 from https://files.pythonhosted.org/packages/7a/fa/bab2170fc8b47a4c591e7ab821fc1fe3d4b10292753f47acba7323eb3d66/psygnal-0.12.0-cp311-cp311-macosx_11_0_arm64.whl.metadata
#   Downloading psygnal-0.12.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (7.7 kB)
# Requirement already satisfied: comm>=0.1.3 in ./tf_env_py311/lib/python3.11/site-packages (from ipywidgets->leafmap->geoai-py) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in ./tf_env_py311/lib/python3.11/site-packages (from ipywidgets->leafmap->geoai-py) (9.0.1)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in ./tf_env_py311/lib/python3.11/site-packages (from ipywidgets->leafmap->geoai-py) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in ./tf_env_py311/lib/python3.11/site-packages (from ipywidgets->leafmap->geoai-py) (3.0.13)
# Collecting traittypes>=0.0.6 (from bqplot->leafmap->geoai-py)
#   Obtaining dependency information for traittypes>=0.0.6 from https://files.pythonhosted.org/packages/9c/d1/8d5bd662703cc1764d986f6908a608777305946fa634d34c470cd4a1e729/traittypes-0.2.1-py2.py3-none-any.whl.metadata
#   Downloading traittypes-0.2.1-py2.py3-none-any.whl.metadata (1.0 kB)
# Collecting cachelib>=0.9.0 (from Flask-Caching->localtileserver->geoai-py)
#   Obtaining dependency information for cachelib>=0.9.0 from https://files.pythonhosted.org/packages/9b/42/960fc9896ddeb301716fdd554bab7941c35fb90a1dc7260b77df3366f87f/cachelib-0.13.0-py3-none-any.whl.metadata
#   Downloading cachelib-0.13.0-py3-none-any.whl.metadata (2.0 kB)
# Collecting branca>=0.6.0 (from folium->leafmap->geoai-py)
#   Obtaining dependency information for branca>=0.6.0 from https://files.pythonhosted.org/packages/f8/9d/91cddd38bd00170aad1a4b198c47b4ed716be45c234e09b835af41f4e717/branca-0.8.1-py3-none-any.whl.metadata
#   Downloading branca-0.8.1-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: beautifulsoup4 in ./tf_env_py311/lib/python3.11/site-packages (from gdown->leafmap->geoai-py) (4.13.3)
# Collecting geographiclib<3,>=1.52 (from geopy->contextily->geoai-py)
#   Obtaining dependency information for geographiclib<3,>=1.52 from https://files.pythonhosted.org/packages/9f/5a/a26132406f1f40cf51ea349a5f11b0a46cec02a2031ff82e391c2537247a/geographiclib-2.0-py3-none-any.whl.metadata
#   Downloading geographiclib-2.0-py3-none-any.whl.metadata (1.4 kB)
# Collecting jupyter-leaflet<0.20,>=0.19 (from ipyleaflet->leafmap->geoai-py)
#   Obtaining dependency information for jupyter-leaflet<0.20,>=0.19 from https://files.pythonhosted.org/packages/81/7c/3ade59500a358b9018a996d00c26eaede79f76ed362b7051bc5038d4a0d4/jupyter_leaflet-0.19.2-py3-none-any.whl.metadata
#   Downloading jupyter_leaflet-0.19.2-py3-none-any.whl.metadata (2.4 kB)
# Collecting ipyvue<2,>=1.7 (from ipyvuetify->leafmap->geoai-py)
# ...
# Downloading kornia-0.8.0-py2.py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 9.6 MB/s eta 0:00:00ta 0:00:01
# Downloading lightly-1.5.19-py3-none-any.whl (850 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 850.8/850.8 kB 8.4 MB/s eta 0:00:00:00:0100:01
# Downloading opencv_python_headless-4.11.0.86-cp37-abi3-macosx_13_0_arm64.whl (37.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.3/37.3 MB 10.0 MB/s eta 0:00:0000:0100:01
# Downloading pandas-2.2.3-cp311-cp311-macosx_11_0_arm64.whl (11.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 10.8 MB/s eta 0:00:0000:0100:01
# Downloading pyarrow-19.0.1-cp311-cp311-macosx_12_0_arm64.whl (30.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.7/30.7 MB 9.5 MB/s eta 0:00:00:00:0100:01
# Downloading pydantic-2.10.6-py3-none-any.whl (431 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 431.7/431.7 kB 4.5 MB/s eta 0:00:0000:0100:01
# Downloading pydantic_core-2.27.2-cp311-cp311-macosx_11_0_arm64.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 7.1 MB/s eta 0:00:00a 0:00:01m
# Downloading pyogrio-0.10.0-cp311-cp311-macosx_12_0_arm64.whl (15.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.1/15.1 MB 10.2 MB/s eta 0:00:0000:0100:01
# Downloading pyproj-3.7.1-cp311-cp311-macosx_14_0_arm64.whl (4.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 11.2 MB/s eta 0:00:00a 0:00:01
# Downloading pystac-1.12.2-py3-none-any.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.2/194.2 kB 10.5 MB/s eta 0:00:00
# Downloading pytz-2025.1-py2.py3-none-any.whl (507 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 507.9/507.9 kB 14.6 MB/s eta 0:00:00
# Downloading regex-2024.11.6-cp311-cp311-macosx_11_0_arm64.whl (284 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 284.6/284.6 kB 13.6 MB/s eta 0:00:00
# Downloading rtree-1.4.0-py3-none-macosx_11_0_arm64.whl (439 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 439.8/439.8 kB 9.9 MB/s eta 0:00:00:00:01
# Downloading safetensors-0.5.3-cp38-abi3-macosx_11_0_arm64.whl (418 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 418.4/418.4 kB 10.4 MB/s eta 0:00:0000:01
# Downloading segmentation_models_pytorch-0.4.0-py3-none-any.whl (121 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.3/121.3 kB 4.1 MB/s eta 0:00:00
# Downloading shapely-2.0.7-cp311-cp311-macosx_11_0_arm64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 10.3 MB/s eta 0:00:0000:0100:01
# Downloading simpervisor-1.0.0-py3-none-any.whl (8.3 kB)
# Downloading threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Downloading timm-1.0.15-py3-none-any.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 12.7 MB/s eta 0:00:00a 0:00:01
# Downloading tokenizers-0.21.0-cp39-abi3-macosx_11_0_arm64.whl (2.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 10.6 MB/s eta 0:00:00a 0:00:01
# Downloading torchmetrics-1.6.2-py3-none-any.whl (931 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 931.6/931.6 kB 10.4 MB/s eta 0:00:0000:0100:01
# Downloading torchvision-0.21.0-cp311-cp311-macosx_11_0_arm64.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 10.6 MB/s eta 0:00:0000:0100:01
# Downloading xarray-2025.1.2-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 10.7 MB/s eta 0:00:00a 0:00:01
# Using cached affine-2.4.0-py3-none-any.whl (15 kB)
# Downloading aiohttp-3.11.13-cp311-cp311-macosx_11_0_arm64.whl (455 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 456.0/456.0 kB 9.8 MB/s eta 0:00:00ta 0:00:01
# Downloading anywidget-0.9.15-py3-none-any.whl (219 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 219.1/219.1 kB 8.0 MB/s eta 0:00:00
# Downloading bqplot-0.12.44-py2.py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 10.8 MB/s eta 0:00:00a 0:00:01
# Using cached colour-0.1.5-py2.py3-none-any.whl (23 kB)
# Downloading duckdb-1.2.1-cp311-cp311-macosx_12_0_arm64.whl (15.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.3/15.3 MB 11.5 MB/s eta 0:00:0000:0100:01
# Downloading filelock-3.17.0-py3-none-any.whl (16 kB)
# Downloading Flask_Caching-2.3.1-py3-none-any.whl (28 kB)
# Downloading flask_cors-5.0.1-py3-none-any.whl (11 kB)
# Downloading folium-0.19.5-py2.py3-none-any.whl (110 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.9/110.9 kB 9.6 MB/s eta 0:00:00
# Downloading gdown-5.2.0-py3-none-any.whl (18 kB)
# Downloading geojson-3.2.0-py3-none-any.whl (15 kB)
# Downloading geopy-2.4.1-py3-none-any.whl (125 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.4/125.4 kB 6.6 MB/s eta 0:00:00
# Downloading ipyevents-2.0.2-py3-none-any.whl (101 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.8/101.8 kB 9.7 MB/s eta 0:00:00
# Using cached ipyfilechooser-0.6.0-py3-none-any.whl (11 kB)
# Downloading ipyleaflet-0.19.2-py3-none-any.whl (31 kB)
# Downloading xyzservices-2025.1.0-py3-none-any.whl (88 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.4/88.4 kB 8.9 MB/s eta 0:00:00
# Downloading ipyvuetify-1.11.1-py2.py3-none-any.whl (7.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 5.7 MB/s eta 0:00:0000:01m0:01m
# Downloading mercantile-1.2.1-py3-none-any.whl (14 kB)
# Downloading plotly-6.0.0-py3-none-any.whl (14.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.8/14.8 MB 10.2 MB/s eta 0:00:0000:0100:01
# Using cached pyshp-2.3.1-py2.py3-none-any.whl (46 kB)
# Downloading python_box-7.3.2-cp311-cp311-macosx_10_9_universal2.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 5.6 MB/s eta 0:00:00:00:0100:01
# Using cached python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Downloading rio_cogeo-5.4.1-py3-none-any.whl (20 kB)
# Downloading rio_tiler-7.5.0-py3-none-any.whl (267 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 267.5/267.5 kB 9.6 MB/s eta 0:00:00
# Downloading scooby-0.10.0-py3-none-any.whl (18 kB)
# Downloading server_thread-0.3.0-py3-none-any.whl (6.6 kB)
# Using cached whiteboxgui-2.3.0-py2.py3-none-any.whl (108 kB)
# Downloading aenum-3.1.15-py3-none-any.whl (137 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.6/137.6 kB 9.3 MB/s eta 0:00:00
# Downloading aiohappyeyeballs-2.5.0-py3-none-any.whl (15 kB)
# Downloading aiosignal-1.3.2-py2.py3-none-any.whl (7.6 kB)
# Downloading aniso8601-10.0.0-py2.py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.8/52.8 kB 3.5 MB/s eta 0:00:00
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading bitsandbytes-0.42.0-py3-none-any.whl (105.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.0/105.0 MB 8.5 MB/s eta 0:00:00:00:0100:01
# Downloading blinker-1.9.0-py3-none-any.whl (8.5 kB)
# Downloading branca-0.8.1-py3-none-any.whl (26 kB)
# Downloading cachelib-0.13.0-py3-none-any.whl (20 kB)
# Downloading frozenlist-1.5.0-cp311-cp311-macosx_11_0_arm64.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.5/52.5 kB 3.8 MB/s eta 0:00:00
# Downloading geographiclib-2.0-py3-none-any.whl (40 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.3/40.3 kB 4.0 MB/s eta 0:00:00
# Downloading hydra_core-1.3.2-py3-none-any.whl (154 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 14.5 MB/s eta 0:00:00
# Downloading ipyvue-1.11.2-py2.py3-none-any.whl (2.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 11.1 MB/s eta 0:00:0000:0100:01
# Downloading itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# Downloading jupyter_leaflet-0.19.2-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 11.1 MB/s eta 0:00:00a 0:00:01
# Downloading kornia_rs-0.1.8-cp311-cp311-macosx_11_0_arm64.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 11.2 MB/s eta 0:00:00a 0:00:01
# Downloading lightly_utils-0.0.2-py3-none-any.whl (6.4 kB)
# Downloading lightning_utilities-0.14.0-py3-none-any.whl (28 kB)
# Downloading morecantile-6.2.0-py3-none-any.whl (49 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.5/49.5 kB 3.2 MB/s eta 0:00:00
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Downloading multidict-6.1.0-cp311-cp311-macosx_11_0_arm64.whl (29 kB)
# Downloading narwhals-1.30.0-py3-none-any.whl (313 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.6/313.6 kB 12.2 MB/s eta 0:00:00
# Downloading omegaconf-2.3.0-py3-none-any.whl (79 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 7.5 MB/s eta 0:00:00
# Downloading propcache-0.3.0-cp311-cp311-macosx_11_0_arm64.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.4/45.4 kB 4.5 MB/s eta 0:00:00
# Downloading psygnal-0.12.0-cp311-cp311-macosx_11_0_arm64.whl (430 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 430.1/430.1 kB 10.1 MB/s eta 0:00:0000:01
# Downloading pytorch_lightning-2.5.0.post0-py3-none-any.whl (819 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 819.3/819.3 kB 10.7 MB/s eta 0:00:00a 0:00:01
# Downloading simsimd-6.2.1-cp311-cp311-macosx_11_0_arm64.whl (93 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.5/93.5 kB 6.2 MB/s eta 0:00:00
# Downloading stringzilla-3.12.3-cp311-cp311-macosx_11_0_arm64.whl (79 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.2/79.2 kB 6.2 MB/s eta 0:00:00
# Downloading tensorboardX-2.6.2.2-py2.py3-none-any.whl (101 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 6.9 MB/s eta 0:00:00
# Using cached traittypes-0.2.1-py2.py3-none-any.whl (8.6 kB)
# Downloading tzdata-2025.1-py2.py3-none-any.whl (346 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 346.8/346.8 kB 12.0 MB/s eta 0:00:00
# Downloading yarl-1.18.3-cp311-cp311-macosx_11_0_arm64.whl (92 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.3/92.3 kB 6.0 MB/s eta 0:00:00
# Downloading cachetools-5.5.2-py3-none-any.whl (10 kB)
# Downloading color_operations-0.1.6-cp311-cp311-macosx_11_0_arm64.whl (48 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.0/49.0 kB 1.9 MB/s eta 0:00:00
# Downloading importlib_resources-6.5.2-py3-none-any.whl (37 kB)
# Using cached ipytree-0.2.2-py2.py3-none-any.whl (1.3 MB)
# Downloading lightning-2.5.0.post0-py3-none-any.whl (815 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 815.2/815.2 kB 9.6 MB/s eta 0:00:00:00:0100:01
# Downloading numexpr-2.10.2-cp311-cp311-macosx_11_0_arm64.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.7/134.7 kB 10.0 MB/s eta 0:00:00
# Downloading uvicorn-0.34.0-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.3/62.3 kB 4.8 MB/s eta 0:00:00
# Downloading whitebox-2.3.6-py2.py3-none-any.whl (74 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.0/74.0 kB 6.0 MB/s eta 0:00:00
# Downloading docstring_parser-0.16-py3-none-any.whl (36 kB)
# Using cached PySocks-1.7.1-py3-none-any.whl (16 kB)
# Downloading typeshed_client-2.7.0-py3-none-any.whl (624 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 624.4/624.4 kB 8.7 MB/s eta 0:00:00ta 0:00:01
# Downloading jsonargparse-4.37.0-py3-none-any.whl (216 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 216.3/216.3 kB 9.5 MB/s eta 0:00:00
# Downloading munch-4.0.0-py2.py3-none-any.whl (9.9 kB)
# Building wheels for collected packages: efficientnet-pytorch, antlr4-python3-runtime, pretrainedmodels
#   Building wheel for efficientnet-pytorch (setup.py) ... done
#   Created wheel for efficientnet-pytorch: filename=efficientnet_pytorch-0.7.1-py3-none-any.whl size=16428 sha256=df6abf71c0aa823fb55952d2ba3d5811ecf097bc575d6178dd46002f1b24157d
#   Stored in directory: /Users/dynamicpacific/Library/Caches/pip/wheels/8b/6f/9b/231a832f811ab6ebb1b32455b177ffc6b8b1cd8de19de70c09
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144555 sha256=a98bf5fdd48000380f509696124aab66f45b322140a05a304d7e314c6cb4f6d4
#   Stored in directory: /Users/dynamicpacific/Library/Caches/pip/wheels/1a/97/32/461f837398029ad76911109f07047fde1d7b661a147c7c56d1
#   Building wheel for pretrainedmodels (setup.py) ... done
#   Created wheel for pretrainedmodels: filename=pretrainedmodels-0.7.4-py3-none-any.whl size=60944 sha256=2a09cb58ef59b1e704e3182388f7daa218aea02c37a07531fb3ab8149a3073d9
#   Stored in directory: /Users/dynamicpacific/Library/Caches/pip/wheels/5f/5b/96/fd94bc35962d7c6b699e8814db545155ac91d2b95785e1b035
# Successfully built efficientnet-pytorch antlr4-python3-runtime pretrainedmodels
# Installing collected packages: stringzilla, simsimd, pytz, mpmath, colour, antlr4-python3-runtime, aniso8601, aenum, xyzservices, tzdata, traittypes, tqdm, threadpoolctl, tensorboardX, sympy, simpervisor, shapely, scooby, safetensors, rtree, regex, python-dotenv, python-box, PySocks, pyshp, pyproj, pyogrio, pydantic-core, pyarrow, psygnal, propcache, opencv-python-headless, omegaconf, numexpr, narwhals, munch, multidict, lightning-utilities, lightly_utils, kornia_rs, jupyter-leaflet, jsonargparse, joblib, itsdangerous, importlib-resources, geojson, geographiclib, fsspec, frozenlist, filelock, einops, duckdb, docstring-parser, color-operations, click, cachetools, cachelib, blinker, annotated-types, aiohappyeyeballs, affine, yarl, whitebox, uvicorn, typeshed-client, torch, scikit-learn, pystac, pydantic, plotly, pandas, overturemaps, mercantile, hydra-core, huggingface_hub, geopy, flask, cligj, click-plugins, branca, bitsandbytes, albucore, aiosignal, xarray, torchvision, torchmetrics, tokenizers, server-thread, rasterio, morecantile, mapclassify, kornia, geopandas, gdown, folium, flask-cors, Flask-Caching, fiona, efficientnet-pytorch, albumentations, aiohttp, transformers, timm, rioxarray, rio-tiler, rio-cogeo, pretrainedmodels, ipyvue, ipytree, ipyleaflet, ipyfilechooser, ipyevents, flask-restx, contextily, bqplot, anywidget, whiteboxgui, segmentation-models-pytorch, pytorch_lightning, pystac-client, localtileserver, ipyvuetify, planetary-computer, lightning, lightly, leafmap, torchgeo, jupyter-server-proxy, geoai-py
# Successfully installed Flask-Caching-2.3.1 PySocks-1.7.1 aenum-3.1.15 affine-2.4.0 aiohappyeyeballs-2.5.0 aiohttp-3.11.13 aiosignal-1.3.2 albucore-0.0.23 albumentations-2.0.5 aniso8601-10.0.0 annotated-types-0.7.0 antlr4-python3-runtime-4.9.3 anywidget-0.9.15 bitsandbytes-0.42.0 blinker-1.9.0 bqplot-0.12.44 branca-0.8.1 cachelib-0.13.0 cachetools-5.5.2 click-8.1.8 click-plugins-1.1.1 cligj-0.7.2 color-operations-0.1.6 colour-0.1.5 contextily-1.6.2 docstring-parser-0.16 duckdb-1.2.1 efficientnet-pytorch-0.7.1 einops-0.8.1 filelock-3.17.0 fiona-1.10.1 flask-3.1.0 flask-cors-5.0.1 flask-restx-1.3.0 folium-0.19.5 frozenlist-1.5.0 fsspec-2025.3.0 gdown-5.2.0 geoai-py-0.3.6 geographiclib-2.0 geojson-3.2.0 geopandas-1.0.1 geopy-2.4.1 huggingface_hub-0.29.2 hydra-core-1.3.2 importlib-resources-6.5.2 ipyevents-2.0.2 ipyfilechooser-0.6.0 ipyleaflet-0.19.2 ipytree-0.2.2 ipyvue-1.11.2 ipyvuetify-1.11.1 itsdangerous-2.2.0 joblib-1.4.2 jsonargparse-4.37.0 jupyter-leaflet-0.19.2 jupyter-server-proxy-4.4.0 kornia-0.8.0 kornia_rs-0.1.8 leafmap-0.42.13 lightly-1.5.19 lightly_utils-0.0.2 lightning-2.5.0.post0 lightning-utilities-0.14.0 localtileserver-0.10.6 mapclassify-2.8.1 mercantile-1.2.1 morecantile-6.2.0 mpmath-1.3.0 multidict-6.1.0 munch-4.0.0 narwhals-1.30.0 numexpr-2.10.2 omegaconf-2.3.0 opencv-python-headless-4.11.0.86 overturemaps-0.12.0 pandas-2.2.3 planetary-computer-1.0.0 plotly-6.0.0 pretrainedmodels-0.7.4 propcache-0.3.0 psygnal-0.12.0 pyarrow-19.0.1 pydantic-2.10.6 pydantic-core-2.27.2 pyogrio-0.10.0 pyproj-3.7.1 pyshp-2.3.1 pystac-1.12.2 pystac-client-0.8.6 python-box-7.3.2 python-dotenv-1.0.1 pytorch_lightning-2.5.0.post0 pytz-2025.1 rasterio-1.4.3 regex-2024.11.6 rio-cogeo-5.4.1 rio-tiler-7.5.0 rioxarray-0.18.2 rtree-1.4.0 safetensors-0.5.3 scikit-learn-1.6.1 scooby-0.10.0 segmentation-models-pytorch-0.4.0 server-thread-0.3.0 shapely-2.0.7 simpervisor-1.0.0 simsimd-6.2.1 stringzilla-3.12.3 sympy-1.13.1 tensorboardX-2.6.2.2 threadpoolctl-3.5.0 timm-1.0.15 tokenizers-0.21.0 torch-2.6.0 torchgeo-0.6.2 torchmetrics-1.6.2 torchvision-0.21.0 tqdm-4.67.1 traittypes-0.2.1 transformers-4.49.0 typeshed-client-2.7.0 tzdata-2025.1 uvicorn-0.34.0 whitebox-2.3.6 whiteboxgui-2.3.0 xarray-2025.1.2 xyzservices-2025.1.0 yarl-1.18.3
#
# [notice] A new release of pip is available: 23.2.1 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
import geoai

# %%
raster_url = (
    "https://huggingface.co/datasets/giswqs/geospatial/resolve/main/trees_brazil.tif"
)
raster_path = geoai.download_file(raster_url)
# Out:
# trees_brazil.tif: 100%|██████████| 3.93M/3.93M [00:00<00:00, 11.6MB/s]

# %%
geoai.view_raster(raster_url)
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1fd2ca5bebfb1768e7a435d27b8f819e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.css&quot;/&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/ljagis/leaflet-measure@2.1.7/dist/leaflet-measure.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/ljagis/leaflet-measure@2.1.7/dist/leaflet-measure.min.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1fd2ca5bebfb1768e7a435d27b8f819e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1fd2ca5bebfb1768e7a435d27b8f819e = L.map(
#                 &quot;map_1fd2ca5bebfb1768e7a435d27b8f819e&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 2,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
#   &quot;drawExport&quot;: false,
#   &quot;layersControl&quot;: true,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_1fd2ca5bebfb1768e7a435d27b8f819e);
#
#
#
#
#
#             var tile_layer_507e5fa85f938302e94fc098b65c6c8c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 24,
#   &quot;maxNativeZoom&quot;: 24,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_507e5fa85f938302e94fc098b65c6c8c.addTo(map_1fd2ca5bebfb1768e7a435d27b8f819e);
#
#
#             L.control.fullscreen(
#                 {
#   &quot;position&quot;: &quot;topleft&quot;,
#   &quot;title&quot;: &quot;Full Screen&quot;,
#   &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;,
#   &quot;forceSeparateButton&quot;: false,
# }
#             ).addTo(map_1fd2ca5bebfb1768e7a435d27b8f819e);
#
#
#             var options = {
#               position: &quot;topleft&quot;,
#               draw: {},
#               edit: {},
#             }
#                 // FeatureGroup is to store editable layers.
#                 var drawnItems_draw_control_4dcf0e2faffe81b9fa120d5d2e0ad9d3 =
#                     new L.featureGroup().addTo(
#                         map_1fd2ca5bebfb1768e7a435d27b8f819e
#                     );
#
#             options.edit.featureGroup = drawnItems_draw_control_4dcf0e2faffe81b9fa120d5d2e0ad9d3;
#             var draw_control_4dcf0e2faffe81b9fa120d5d2e0ad9d3 = new L.Control.Draw(
#                 options
#             ).addTo( map_1fd2ca5bebfb1768e7a435d27b8f819e );
#             map_1fd2ca5bebfb1768e7a435d27b8f819e.on(L.Draw.Event.CREATED, function(e) {
#                 var layer = e.layer,
#                     type = e.layerType;
#                 var coords = JSON.stringify(layer.toGeoJSON());
#                 layer.on(&#x27;click&#x27;, function() {
#                     alert(coords);
#                     console.log(coords);
#                 });
#                 drawnItems_draw_control_4dcf0e2faffe81b9fa120d5d2e0ad9d3.addLayer(layer);
#             });
#             map_1fd2ca5bebfb1768e7a435d27b8f819e.on(&#x27;draw:created&#x27;, function(e) {
#                 drawnItems_draw_control_4dcf0e2faffe81b9fa120d5d2e0ad9d3.addLayer(e.layer);
#             });
#
#
#
#
#             var measure_control_93ee2ac9aab4ef65ebf9e0a5f73b8c27 = new L.Control.Measure(
#                 {
#   &quot;position&quot;: &quot;bottomleft&quot;,
#   &quot;primaryLengthUnit&quot;: &quot;meters&quot;,
#   &quot;secondaryLengthUnit&quot;: &quot;miles&quot;,
#   &quot;primaryAreaUnit&quot;: &quot;sqmeters&quot;,
#   &quot;secondaryAreaUnit&quot;: &quot;acres&quot;,
# });
#             map_1fd2ca5bebfb1768e7a435d27b8f819e.addControl(measure_control_93ee2ac9aab4ef65ebf9e0a5f73b8c27);
#
#             // Workaround for using this plugin with Leaflet&gt;=1.8.0
#             // https://github.com/ljagis/leaflet-measure/issues/171
#             L.Control.Measure.include({
#                 _setCaptureMarkerIcon: function () {
#                     // disable autopan
#                     this._captureMarker.options.autoPanOnFocus = false;
#                     // default function
#                     this._captureMarker.setIcon(
#                         L.divIcon({
#                             iconSize: this._map.getSize().multiplyBy(2)
#                         })
#                     );
#                 },
#             });
#
#
#
#
#             var geocoderOpts_geocoder_64e37bd8d591730c8da7ff820a4f7e77 = {
#   &quot;collapsed&quot;: true,
#   &quot;position&quot;: &quot;topleft&quot;,
#   &quot;defaultMarkGeocode&quot;: true,
#   &quot;zoom&quot;: 11,
#   &quot;provider&quot;: &quot;nominatim&quot;,
#   &quot;providerOp

# %%
segmenter = geoai.CLIPSegmentation(tile_size=512, overlap=32)
# Out:
# preprocessor_config.json:   0%|          | 0.00/380 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/974 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.06M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/525k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/472 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/4.73k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/603M [00:00<?, ?B/s]
# Model loaded on cpu

# %%
output_path = "tree_masks.tif"
text_prompt = "trees"

# %%
segmenter.segment_image(
    raster_path,
    output_path=output_path,
    text_prompt=text_prompt,
    threshold=0.5,
    smoothing_sigma=1.0,
)
# Out:
# Processing tiles: 100%|██████████| 15/15 [00:11<00:00,  1.26it/s]
# Segmentation saved to tree_masks.tif
# 'tree_masks.tif'

# %%
geoai.view_raster(
    output_path,
    nodata=0,
    opacity=0.8,
    colormap="greens",
    layer_name="Trees",
    basemap=raster_url,
)
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6a452b15e8fa5bb7858d6b53ef06adc0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.css&quot;/&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/ljagis/leaflet-measure@2.1.7/dist/leaflet-measure.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/ljagis/leaflet-measure@2.1.7/dist/leaflet-measure.min.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6a452b15e8fa5bb7858d6b53ef06adc0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6a452b15e8fa5bb7858d6b53ef06adc0 = L.map(
#                 &quot;map_6a452b15e8fa5bb7858d6b53ef06adc0&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 2,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
#   &quot;drawExport&quot;: false,
#   &quot;layersControl&quot;: true,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_6a452b15e8fa5bb7858d6b53ef06adc0);
#
#
#
#
#
#             var tile_layer_0fb0f6eb2d15439722bcb7573d0b31e6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 24,
#   &quot;maxNativeZoom&quot;: 24,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0fb0f6eb2d15439722bcb7573d0b31e6.addTo(map_6a452b15e8fa5bb7858d6b53ef06adc0);
#
#
#             L.control.fullscreen(
#                 {
#   &quot;position&quot;: &quot;topleft&quot;,
#   &quot;title&quot;: &quot;Full Screen&quot;,
#   &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;,
#   &quot;forceSeparateButton&quot;: false,
# }
#             ).addTo(map_6a452b15e8fa5bb7858d6b53ef06adc0);
#
#
#             var options = {
#               position: &quot;topleft&quot;,
#               draw: {},
#               edit: {},
#             }
#                 // FeatureGroup is to store editable layers.
#                 var drawnItems_draw_control_b4210a90837844e58708a46ca75f864b =
#                     new L.featureGroup().addTo(
#                         map_6a452b15e8fa5bb7858d6b53ef06adc0
#                     );
#
#             options.edit.featureGroup = drawnItems_draw_control_b4210a90837844e58708a46ca75f864b;
#             var draw_control_b4210a90837844e58708a46ca75f864b = new L.Control.Draw(
#                 options
#             ).addTo( map_6a452b15e8fa5bb7858d6b53ef06adc0 );
#             map_6a452b15e8fa5bb7858d6b53ef06adc0.on(L.Draw.Event.CREATED, function(e) {
#                 var layer = e.layer,
#                     type = e.layerType;
#                 var coords = JSON.stringify(layer.toGeoJSON());
#                 layer.on(&#x27;click&#x27;, function() {
#                     alert(coords);
#                     console.log(coords);
#                 });
#                 drawnItems_draw_control_b4210a90837844e58708a46ca75f864b.addLayer(layer);
#             });
#             map_6a452b15e8fa5bb7858d6b53ef06adc0.on(&#x27;draw:created&#x27;, function(e) {
#                 drawnItems_draw_control_b4210a90837844e58708a46ca75f864b.addLayer(e.layer);
#             });
#
#
#
#
#             var measure_control_14044d2c71903fed940c2b104b7b0a58 = new L.Control.Measure(
#                 {
#   &quot;position&quot;: &quot;bottomleft&quot;,
#   &quot;primaryLengthUnit&quot;: &quot;meters&quot;,
#   &quot;secondaryLengthUnit&quot;: &quot;miles&quot;,
#   &quot;primaryAreaUnit&quot;: &quot;sqmeters&quot;,
#   &quot;secondaryAreaUnit&quot;: &quot;acres&quot;,
# });
#             map_6a452b15e8fa5bb7858d6b53ef06adc0.addControl(measure_control_14044d2c71903fed940c2b104b7b0a58);
#
#             // Workaround for using this plugin with Leaflet&gt;=1.8.0
#             // https://github.com/ljagis/leaflet-measure/issues/171
#             L.Control.Measure.include({
#                 _setCaptureMarkerIcon: function () {
#                     // disable autopan
#                     this._captureMarker.options.autoPanOnFocus = false;
#                     // default function
#                     this._captureMarker.setIcon(
#                         L.divIcon({
#                             iconSize: this._map.getSize().multiplyBy(2)
#                         })
#                     );
#                 },
#             });
#
#
#
#
#             var geocoderOpts_geocoder_13f1a6a588cfc36d7a8acd2e711252fa = {
#   &quot;collapsed&quot;: true,
#   &quot;position&quot;: &quot;topleft&quot;,
#   &quot;defaultMarkGeocode&quot;: true,
#   &quot;zoom&quot;: 11,
#   &quot;provider&quot;: &quot;nominatim&quot;,
#   &quot;providerOp
# 2025-03-10 16:36:19,820 - ERROR - Exception possibly due to cache backend.
# Traceback (most recent call last):
#   File "/Users/dynamicpacific/Dropbox/DEV/forestai-platform-model/tf_env_py311/lib/python3.11/site-packages/flask_caching/__init__.py", line 435, in decorated_function
#     self.cache.set(
#   File "/Users/dynamicpacific/Dropbox/DEV/forestai-platform-model/tf_env_py311/lib/python3.11/site-packages/cachelib/simple.py", line 75, in set
#     self._prune()
#   File "/Users/dynamicpacific/Dropbox/DEV/forestai-platform-model/tf_env_py311/lib/python3.11/site-packages/cachelib/simple.py", line 52, in _prune
#     self._remove_expired(now)
#   File "/Users/dynamicpacific/Dropbox/DEV/forestai-platform-model/tf_env_py311/lib/python3.11/site-packages/cachelib/simple.py", line 36, in _remove_expired
#     toremove = [k for k, (expires, _) in self._cache.items() if expires < now]
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/dynamicpacific/Dropbox/DEV/forestai-platform-model/tf_env_py311/lib/python3.11/site-packages/cachelib/simple.py", line 36, in <listcomp>
#     toremove = [k for k, (expires, _) in self._cache.items() if expires < now]
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# RuntimeError: dictionary keys changed during iteration
# 2025-03-10 16:36:27,390 - ERROR - Exception possibly due to cache backend.
# Traceback (most recent call last):
#   File "/Users/dynamicpacific/Dropbox/DEV/forestai-platform-model/tf_env_py311/lib/python3.11/site-packages/flask_caching/__init__.py", line 435, in decorated_function
#     self.cache.set(
#   File "/Users/dynamicpacific/Dropbox/DEV/forestai-platform-model/tf_env_py311/lib/python3.11/site-packages/cachelib/simple.py", line 75, in set
#     self._prune()
#   File "/Users/dynamicpacific/Dropbox/DEV/forestai-platform-model/tf_env_py311/lib/python3.11/site-packages/cachelib/simple.py", line 52, in _prune
#     self._remove_expired(now)
#   File "/Users/dynamicpacific/Dropbox/DEV/forestai-platform-model/tf_env_py311/lib/python3.11/site-packages/cachelib/simple.py", line 36, in _remove_expired
#     toremove = [k for k, (expires, _) in self._cache.items() if expires < now]
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/dynamicpacific/Dropbox/DEV/forestai-platform-model/tf_env_py311/lib/python3.11/site-packages/cachelib/simple.py", line 36, in <listcomp>
#     toremove = [k for k, (expires, _) in self._cache.items() if expires < now]
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# RuntimeError: dictionary keys changed during iteration
# 2025-03-10 16:37:00,289 - ERROR - Exception possibly due to cache backend.
# Traceback (most recent call last):
#   File "/Users/dynamicpacific/Dropbox/DEV/forestai-platform-model/tf_env_py311/lib/python3.11/site-packages/flask_caching/__init__.py", line 435, in decorated_function
#     self.cache.set(
#   File "/Users/dynamicpacific/Dropbox/DEV/forestai-platform-model/tf_env_py311/lib/python3.11/site-packages/cachelib/simple.py", line 75, in set
#     self._prune()
#   File "/Users/dynamicpacific/Dropbox/DEV/forestai-platform-model/tf_env_py311/lib/python3.11/site-packages/cachelib/simple.py", line 52, in _prune
#     self._remove_expired(now)
#   File "/Users/dynamicpacific/Dropbox/DEV/forestai-platform-model/tf_env_py311/lib/python3.11/site-packages/cachelib/simple.py", line 36, in _remove_expired
#     toremove = [k for k, (expires, _) in self._cache.items() if expires < now]
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/dynamicpacific/Dropbox/DEV/forestai-platform-model/tf_env_py311/lib/python3.11/site-packages/cachelib/simple.py", line 36, in <listcomp>
#     toremove = [k for k, (expires, _) in self._cache.items() if expires < now]
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# RuntimeError: dictionary changed size during iteration
# 2025-03-10 16:37:00,370 - ERROR - Exception possibly due to cache backend.
# Traceback (most recent call last):
#   File "/Users/dynamicpacific/Dropbox/DEV/forestai-platform-model/tf_env_py311/lib/python3.11/site-packages/flask_caching/__init__.py", line 435, in decorated_function
#     self.cache.set(
#   File "/Users/dynamicpacific/Dropbox/DEV/forestai-platform-model/tf_env_py311/lib/python3.11/site-packages/cachelib/simple.py", line 75, in set
#     self._prune()
#   File "/Users/dynamicpacific/Dropbox/DEV/forestai-platform-model/tf_env_py311/lib/python3.11/site-packages/cachelib/simple.py", line 52, in _prune
#     self._remove_expired(now)
#   File "/Users/dynamicpacific/Dropbox/DEV/forestai-platform-model/tf_env_py311/lib/python3.11/site-packages/cachelib/simple.py", line 36, in _remove_expired
#     toremove = [k for k, (expires, _) in self._cache.items() if expires < now]
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/dynamicpacific/Dropbox/DEV/forestai-platform-model/tf_env_py311/lib/python3.11/site-packages/cachelib/simple.py", line 36, in <listcomp>
#     toremove = [k for k, (expires, _) in self._cache.items() if expires < now]
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# RuntimeError: dictionary keys changed during iteration

# %%
geoai.create_split_map(
    left_layer=output_path,
    right_layer=raster_url,
    left_label="Trees",
    right_label="Satellite Image",
    left_args={"nodata": 0, "opacity": 0.8, "colormap": "greens"},
    basemap=raster_url,
)
# Out:
# Map(center=[20, 0], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_text…

# %%
import leafmap
from geoai.download import (
    download_naip
)

# %%
m = leafmap.Map(center=[40.785091, -73.968285], zoom=16)
#  Latitude: 40.785091
# Longitude: -73.968285
m.add_basemap("Google Satellite")
m
# Out:
# Map(center=[40.785091, -73.968285], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title'…

# %%
bbox = m.user_roi_bounds()
# if bbox is None:
#     bbox = (-117.6029, 47.65, -117.5936, 47.6563)

# %%
# Download NAIP imagery for the specified region
downloaded_files = download_naip(
    bbox=bbox,
    output_dir="naip_data",
    max_items=1,
    # year=2020,
)

print(f"Downloaded {len(downloaded_files)} files.")
# Out:
# Found 1 NAIP items.
# Downloading item 1/1: m_4007309_sw_18_030_20230820_20231019.tif
# m_4007309_sw_18_030_20230820_20231019.tif: 100%|██████████| 1.14G/1.14G [02:32<00:00, 8.07MiB/s]
# Successfully saved to naip_data/m_4007309_sw_18_030_20230820_20231019.tif
# Downloaded 1 files.

# %%
geoai.view_raster(downloaded_files[0])
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9b5747cce46efb5babec7d177fc553e6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.css&quot;/&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/ljagis/leaflet-measure@2.1.7/dist/leaflet-measure.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/ljagis/leaflet-measure@2.1.7/dist/leaflet-measure.min.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9b5747cce46efb5babec7d177fc553e6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9b5747cce46efb5babec7d177fc553e6 = L.map(
#                 &quot;map_9b5747cce46efb5babec7d177fc553e6&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 2,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
#   &quot;drawExport&quot;: false,
#   &quot;layersControl&quot;: true,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_9b5747cce46efb5babec7d177fc553e6);
#
#
#
#
#
#             var tile_layer_1f8ae1c9616a5d8c9828c94a7325e1f8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 24,
#   &quot;maxNativeZoom&quot;: 24,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1f8ae1c9616a5d8c9828c94a7325e1f8.addTo(map_9b5747cce46efb5babec7d177fc553e6);
#
#
#             L.control.fullscreen(
#                 {
#   &quot;position&quot;: &quot;topleft&quot;,
#   &quot;title&quot;: &quot;Full Screen&quot;,
#   &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;,
#   &quot;forceSeparateButton&quot;: false,
# }
#             ).addTo(map_9b5747cce46efb5babec7d177fc553e6);
#
#
#             var options = {
#               position: &quot;topleft&quot;,
#               draw: {},
#               edit: {},
#             }
#                 // FeatureGroup is to store editable layers.
#                 var drawnItems_draw_control_b2465ca6b0f0ff1a8b83e520b32476e2 =
#                     new L.featureGroup().addTo(
#                         map_9b5747cce46efb5babec7d177fc553e6
#                     );
#
#             options.edit.featureGroup = drawnItems_draw_control_b2465ca6b0f0ff1a8b83e520b32476e2;
#             var draw_control_b2465ca6b0f0ff1a8b83e520b32476e2 = new L.Control.Draw(
#                 options
#             ).addTo( map_9b5747cce46efb5babec7d177fc553e6 );
#             map_9b5747cce46efb5babec7d177fc553e6.on(L.Draw.Event.CREATED, function(e) {
#                 var layer = e.layer,
#                     type = e.layerType;
#                 var coords = JSON.stringify(layer.toGeoJSON());
#                 layer.on(&#x27;click&#x27;, function() {
#                     alert(coords);
#                     console.log(coords);
#                 });
#                 drawnItems_draw_control_b2465ca6b0f0ff1a8b83e520b32476e2.addLayer(layer);
#             });
#             map_9b5747cce46efb5babec7d177fc553e6.on(&#x27;draw:created&#x27;, function(e) {
#                 drawnItems_draw_control_b2465ca6b0f0ff1a8b83e520b32476e2.addLayer(e.layer);
#             });
#
#
#
#
#             var measure_control_b2f8c99fd75c7e16fdbcdeb0708a9dba = new L.Control.Measure(
#                 {
#   &quot;position&quot;: &quot;bottomleft&quot;,
#   &quot;primaryLengthUnit&quot;: &quot;meters&quot;,
#   &quot;secondaryLengthUnit&quot;: &quot;miles&quot;,
#   &quot;primaryAreaUnit&quot;: &quot;sqmeters&quot;,
#   &quot;secondaryAreaUnit&quot;: &quot;acres&quot;,
# });
#             map_9b5747cce46efb5babec7d177fc553e6.addControl(measure_control_b2f8c99fd75c7e16fdbcdeb0708a9dba);
#
#             // Workaround for using this plugin with Leaflet&gt;=1.8.0
#             // https://github.com/ljagis/leaflet-measure/issues/171
#             L.Control.Measure.include({
#                 _setCaptureMarkerIcon: function () {
#                     // disable autopan
#                     this._captureMarker.options.autoPanOnFocus = false;
#                     // default function
#                     this._captureMarker.setIcon(
#                         L.divIcon({
#                             iconSize: this._map.getSize().multiplyBy(2)
#                         })
#                     );
#                 },
#             });
#
#
#
#
#             var geocoderOpts_geocoder_c6ef1e5814cae806e0ead17381e36fdc = {
#   &quot;collapsed&quot;: true,
#   &quot;position&quot;: &quot;topleft&quot;,
#   &quot;defaultMarkGeocode&quot;: true,
#   &quot;zoom&quot;: 11,
#   &quot;provider&quot;: &quot;nominatim&quot;,
#   &quot;providerOp

# %%
segmenter = geoai.CLIPSegmentation(tile_size=512, overlap=32)
# Out:
# Model loaded on cpu

# %%
import sys
sys.path.insert(0, "/Users/dynamicpacific/Dropbox/DEV/geoai")

import geoai  # Now it will load from the local path
segmenter = geoai.CLIPSegmentation(tile_size=512, overlap=32)

# %%
output_path = "tree_masks_centralpark.tif"
text_prompt = "trees"

# %%
segmenter.segment_image(
    downloaded_files[0],
    output_path=output_path,
    text_prompt=text_prompt,
    threshold=0.5,
    smoothing_sigma=1.0,
)
# Out:
# Processing tiles: 100%|██████████| 2173/2173 [21:19<00:00,  1.70it/s]
# Segmentation saved to tree_masks_centralpark.tif
# 'tree_masks_centralpark.tif'

# %%
geoai.view_raster(
    "tree_masks_centralpark.tif",
    nodata=0,
    opacity=0.6,
    colormap="reds",
    layer_name="Trees",
    basemap=downloaded_files[0],
)
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_574ab7fd61a7134cc33ea52b6f12af48 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.css&quot;/&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/ljagis/leaflet-measure@2.1.7/dist/leaflet-measure.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/ljagis/leaflet-measure@2.1.7/dist/leaflet-measure.min.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_574ab7fd61a7134cc33ea52b6f12af48&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_574ab7fd61a7134cc33ea52b6f12af48 = L.map(
#                 &quot;map_574ab7fd61a7134cc33ea52b6f12af48&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 2,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
#   &quot;drawExport&quot;: false,
#   &quot;layersControl&quot;: true,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_574ab7fd61a7134cc33ea52b6f12af48);
#
#
#
#
#
#             var tile_layer_b595979b5b027f1990fed75a9576c290 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 24,
#   &quot;maxNativeZoom&quot;: 24,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b595979b5b027f1990fed75a9576c290.addTo(map_574ab7fd61a7134cc33ea52b6f12af48);
#
#
#             L.control.fullscreen(
#                 {
#   &quot;position&quot;: &quot;topleft&quot;,
#   &quot;title&quot;: &quot;Full Screen&quot;,
#   &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;,
#   &quot;forceSeparateButton&quot;: false,
# }
#             ).addTo(map_574ab7fd61a7134cc33ea52b6f12af48);
#
#
#             var options = {
#               position: &quot;topleft&quot;,
#               draw: {},
#               edit: {},
#             }
#                 // FeatureGroup is to store editable layers.
#                 var drawnItems_draw_control_317ce616c0dd7df287a400c5e846c75b =
#                     new L.featureGroup().addTo(
#                         map_574ab7fd61a7134cc33ea52b6f12af48
#                     );
#
#             options.edit.featureGroup = drawnItems_draw_control_317ce616c0dd7df287a400c5e846c75b;
#             var draw_control_317ce616c0dd7df287a400c5e846c75b = new L.Control.Draw(
#                 options
#             ).addTo( map_574ab7fd61a7134cc33ea52b6f12af48 );
#             map_574ab7fd61a7134cc33ea52b6f12af48.on(L.Draw.Event.CREATED, function(e) {
#                 var layer = e.layer,
#                     type = e.layerType;
#                 var coords = JSON.stringify(layer.toGeoJSON());
#                 layer.on(&#x27;click&#x27;, function() {
#                     alert(coords);
#                     console.log(coords);
#                 });
#                 drawnItems_draw_control_317ce616c0dd7df287a400c5e846c75b.addLayer(layer);
#             });
#             map_574ab7fd61a7134cc33ea52b6f12af48.on(&#x27;draw:created&#x27;, function(e) {
#                 drawnItems_draw_control_317ce616c0dd7df287a400c5e846c75b.addLayer(e.layer);
#             });
#
#
#
#
#             var measure_control_2258c54dea0be2ce4770163acb187d39 = new L.Control.Measure(
#                 {
#   &quot;position&quot;: &quot;bottomleft&quot;,
#   &quot;primaryLengthUnit&quot;: &quot;meters&quot;,
#   &quot;secondaryLengthUnit&quot;: &quot;miles&quot;,
#   &quot;primaryAreaUnit&quot;: &quot;sqmeters&quot;,
#   &quot;secondaryAreaUnit&quot;: &quot;acres&quot;,
# });
#             map_574ab7fd61a7134cc33ea52b6f12af48.addControl(measure_control_2258c54dea0be2ce4770163acb187d39);
#
#             // Workaround for using this plugin with Leaflet&gt;=1.8.0
#             // https://github.com/ljagis/leaflet-measure/issues/171
#             L.Control.Measure.include({
#                 _setCaptureMarkerIcon: function () {
#                     // disable autopan
#                     this._captureMarker.options.autoPanOnFocus = false;
#                     // default function
#                     this._captureMarker.setIcon(
#                         L.divIcon({
#                             iconSize: this._map.getSize().multiplyBy(2)
#                         })
#                     );
#                 },
#             });
#
#
#
#
#             var geocoderOpts_geocoder_165ce968e1e878e0e79f5ff05c538f55 = {
#   &quot;collapsed&quot;: true,
#   &quot;position&quot;: &quot;topleft&quot;,
#   &quot;defaultMarkGeocode&quot;: true,
#   &quot;zoom&quot;: 11,
#   &quot;provider&quot;: &quot;nominatim&quot;,
#   &quot;providerOp

# %%
import os
import tensorflow as tf
import numpy as np
import cv2
import matplotlib.pyplot as plt
from object_detection.utils import visualization_utils as viz_utils
from object_detection.utils import label_map_util

# Install TensorFlow Object Detection API if needed
if not os.path.exists("models"):
    os.system("git clone --depth 1 https://github.com/tensorflow/models.git")
    os.system("cd models/research && protoc object_detection/protos/*.proto --python_out=.")
    os.system("cd models/research && pip install -e .")

# Path to the TensorFlow models directory
PATH_TO_MODELS = "./models"

# Download a pre-trained Mask R-CNN model
MODEL_DATE = "20200711"
MODEL_NAME = "mask_rcnn_inception_resnet_v2_1024x1024_coco17_gpu-8"
MODEL_PATH = f"{PATH_TO_MODELS}/research/object_detection/test_data/{MODEL_NAME}/saved_model"

# Download if model doesn't exist
if not os.path.exists(MODEL_PATH):
    os.makedirs(MODEL_PATH, exist_ok=True)
    os.system(f"wget http://download.tensorflow.org/models/object_detection/tf2/20200711/{MODEL_NAME}.tar.gz")
    os.system(f"tar -xzvf {MODEL_NAME}.tar.gz -C {MODEL_PATH}")

# Load the model
print("Loading model... This might take a minute.")
detect_fn = tf.saved_model.load(MODEL_PATH)

# Load label map
PATH_TO_LABELS = f"{PATH_TO_MODELS}/research/object_detection/data/mscoco_label_map.pbtxt"
category_index = label_map_util.create_category_index_from_labelmap(
    PATH_TO_LABELS, use_display_name=True)

def detect_vegetation(image_path, output_path=None):
    """Detect vegetation in an image using TensorFlow's Object Detection API."""
    # Read image
    image_np = cv2.imread(image_path)
    image_np = cv2.cvtColor(image_np, cv2.COLOR_BGR2RGB)
    
    # Convert image to tensor
    input_tensor = tf.convert_to_tensor(np.expand_dims(image_np, 0), dtype=tf.uint8)
    
    # Run detection
    print("Running inference...")
    detections = detect_fn(input_tensor)
    
    # Extract useful data from the result
    boxes = detections['detection_boxes'][0].numpy()
    classes = detections['detection_classes'][0].numpy().astype(np.int32)
    scores = detections['detection_scores'][0].numpy()
    masks = None
    if 'detection_masks' in detections:
        masks = detections['detection_masks'][0].numpy()
    
    # Define vegetation class IDs (potted plant = 64, tree = 47 in COCO)
    vegetation_class_ids = [47, 64]  # COCO IDs for vegetation-related classes
    
    # Filter for vegetation
    vegetation_indices = np.where(np.isin(classes, vegetation_class_ids) & (scores > 0.5))[0]
    
    # Visualize results
    image_np_with_detections = image_np.copy()
    viz_utils.visualize_boxes_and_labels_on_image_array(
        image_np_with_detections,
        boxes[vegetation_indices],
        classes[vegetation_indices],
        scores[vegetation_indices],
        category_index,
        instance_masks=masks[vegetation_indices] if masks is not None else None,
        use_normalized_coordinates=True,
        line_thickness=2
    )
    
    # Display and save results
    plt.figure(figsize=(12, 8))
    plt.imshow(image_np_with_detections)
    plt.axis('off')
    
    if output_path:
        plt.savefig(output_path, bbox_inches='tight')
        print(f"Detection results saved to {output_path}")
    
    plt.show()
    
    # Print statistics
    num_detections = len(vegetation_indices)
    print(f"Detected {num_detections} vegetation instances")
    
    # Calculate mask areas if masks are available
    if masks is not None and num_detections > 0:
        vegetation_masks = masks[vegetation_indices]
        areas = np.sum(vegetation_masks, axis=(1, 2))
        avg_area = np.mean(areas)
        print(f"Average vegetation area: {avg_area:.2f} pixels")
    
    return {
        'num_detections': num_detections,
        'classes': classes[vegetation_indices],
        'scores': scores[vegetation_indices],
        'boxes': boxes[vegetation_indices],
        'masks': masks[vegetation_indices] if masks is not None else None
    }

# Example usage
# detect_vegetation("../data/Nursury_Screenshot_GoogleEarth.jpg", "../data/output_detection.png")
# Out:
# Cloning TensorFlow 2.x compatible Mask R-CNN repository...
# Cloning into '/Users/dynamicpacific/Dropbox/DEV/forestai-platform-model/TF2-Mask_RCNN'...
# Successfully imported Mask R-CNN modules
# Loading weights from /Users/dynamicpacific/Dropbox/DEV/forestai-platform-model/mask_rcnn_coco.h5
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[27], line 186
#     184 # Test on a sample image
#     185 if __name__ == "__main__":
# --> 186     detect_trees("../data/Nursury_Screenshot_GoogleEarth.jpg", "../data/output_detection.png")
#
# Cell In[27], line 117, in detect_trees(image_path, output_path)
#     115 # Load pre-trained weights
#     116 print(f"Loading weights from {COCO_MODEL_PATH}")
# --> 117 model.load_weights(COCO_MODEL_PATH, by_name=True)
#     119 # Read and process image
#     120 image = cv2.imread(image_path)
#
# File ~/Dropbox/DEV/forestai-platform-model/Mask_RCNN/mrcnn/model.py:2130, in MaskRCNN.load_weights(self, filepath, by_name, exclude)
#    2127     layers = filter(lambda l: l.name not in exclude, layers)
#    2129 if by_name:
# -> 2130     hdf5_format.load_weights_from_hdf5_group_by_name(f, layers)
#    2131 else:
#    2132     hdf5_format.load_weights_from_hdf5_group(f, layers)
#
# File ~/Dropbox/DEV/forestai-platform-model/tf_env_py311/lib/python3.11/site-packages/tensorflow/python/keras/saving/hdf5_format.py:766, in load_weights_from_hdf5_group_by_name(f, layers, skip_mismatch)
#     763 weight_values = [np.asarray(g[weight_name]) for weight_name in weight_names]
#     765 for layer in index.get(name, []):
# --> 766   symbolic_weights = _legacy_weights(layer)
#     767   weight_values = preprocess_weights_for_loading(
#     768       layer, weight_values, original_keras_version, original_backend)
#     769   if len(weight_values) != len(symbolic_weights):
#
# File ~/Dropbox/DEV/forestai-platform-model/tf_env_py311/lib/python3.11/site-packages/tensorflow/python/keras/saving/hdf5_format.py:898, in _legacy_weights(layer)
#     893 weights = layer.trainable_weights + layer.non_trainable_weights
#     894 if any(not isinstance(w, variables_module.Variable) for w in weights):
#     895   raise NotImplementedError(
#     896       'Save or restore weights that is not an instance of `tf.Variable` is '
#     897       'not supported in h5, use `save_format=\'tf\'` instead. Got a model '
# --> 898       'or layer {} with weights {}'.format(layer.__class__.__name__, weights))
#     899 return weights
#
# File ~/Dropbox/DEV/forestai-platform-model/tf_env_py311/lib/python3.11/site-packages/keras/src/backend/common/variables.py:372, in Variable.__repr__(self)
#     370 value = None
#     371 if hasattr(self, "_value") and self._value is not None:
# --> 372     value = backend.core.convert_to_numpy(self._value)
#     373 value_str = f", value={value}" if value is not None else ""
#     374 return (
#     375     f"<Variable path={self.path}, shape={self.shape}, "
#     376     f"dtype={self.dtype}{value_str}>"
#     377 )
#
# File ~/Dropbox/DEV/forestai-platform-model/tf_env_py311/lib/python3.11/site-packages/keras/src/backend/tensorflow/core.py:158, in convert_to_numpy(x)
#     156 elif isinstance(x, tf.RaggedTensor):
#     157     x = x.to_tensor()
# --> 158 return np.array(x)
#
# File ~/Dropbox/DEV/forestai-platform-model/tf_env_py311/lib/python3.11/site-packages/tensorflow/python/ops/resource_variable_ops.py:572, in BaseResourceVariable.__array__(self, dtype)
#     558 """Allows direct conversion to a numpy array.
#     559
#     560 >>> np.array(tf.Variable([1.0]))
#    (...)    564   The variable value as a numpy array.
#     565 """
#     566 # You can't return `self.numpy()` here because for scalars
#     567 # that raises:
#     568 #     ValueError: object __array__ method not producing an array
#     569 # Even `self.read_value().__array__()` and `self.read_value()._numpy()` give
#     570 # the same error. The `EagerTensor` class must be doing something behind the
#     571 # scenes to make `np.array(tf.constant(1))` work.
# --> 572 return numpy_compat.np_asarray(self.numpy(), dtype=dtype)
#
# File ~/Dropbox/DEV/forestai-platform-model/tf_env_py311/lib/python3.11/site-packages/tensorflow/python/ops/resource_variable_ops.py:712, in BaseResourceVariable.numpy(self)
#     710 if context.executing_eagerly():
#     711   return self.read_value().numpy()
# --> 712 raise NotImplementedError(
#     713     "numpy() is only available when eager execution is enabled.")
#
# NotImplementedError: numpy() is only available when eager execution is enabled.

# %%
import os
import sys
import numpy as np
import cv2
import matplotlib.pyplot as plt
import urllib.request
import tarfile

def download_model():
    """Download and extract pre-trained Mask R-CNN model for OpenCV."""
    model_path = "mask_rcnn_inception_v2_coco_2018_01_28"
    weights_path = f"{model_path}/frozen_inference_graph.pb"
    
    # Check if model already exists
    if os.path.exists(weights_path):
        print("Model files already exist.")
        return weights_path
    
    # Download model if needed
    if not os.path.exists(model_path):
        os.makedirs(model_path, exist_ok=True)
        
        # Download the model
        model_url = "http://download.tensorflow.org/models/object_detection/mask_rcnn_inception_v2_coco_2018_01_28.tar.gz"
        tar_file = f"{model_path}.tar.gz"
        
        print(f"Downloading model from {model_url}...")
        urllib.request.urlretrieve(model_url, tar_file)
        
        # Extract the model
        print("Extracting model...")
        with tarfile.open(tar_file, "r:gz") as tar:
            tar.extractall()
        
        # Clean up
        os.remove(tar_file)
    
    return weights_path

def detect_trees(image_path, output_path=None):
    """Detect vegetation in an image using OpenCV's DNN module with a pre-trained network."""
    # Download the model
    weights_path = download_model()
    
    # Load image
    image = cv2.imread(image_path)
    if image is None:
        raise ValueError(f"Could not load image from {image_path}")
    
    height, width = image.shape[:2]
    
    # The pre-trained model expects specific input dimensions
    # This model expects RGB images in specific format
    blob = cv2.dnn.blobFromImage(image, 
                                swapRB=True, 
                                crop=False,
                                size=(800, 600))
    
    # Load the network
    print("Loading model...")
    net = cv2.dnn.readNetFromTensorflow(weights_path)
    
    # Set the input
    net.setInput(blob)
    
    # Run forward pass - get all outputs
    print("Running inference...")
    outs = net.forward()
    
    # Create class list for COCO dataset
    classes = ["background", "person", "bicycle", "car", "motorcycle", "airplane", "bus", "train", "truck", "boat", 
               "traffic light", "fire hydrant", "stop sign", "parking meter", "bench", "bird", "cat", "dog", "horse", "sheep", 
               "cow", "elephant", "bear", "zebra", "giraffe", "backpack", "umbrella", "handbag", "tie", "suitcase", 
               "frisbee", "skis", "snowboard", "sports ball", "kite", "baseball bat", "baseball glove", "skateboard", "surfboard", 
               "tennis racket", "bottle", "wine glass", "cup", "fork", "knife", "spoon", "bowl", "banana", "apple", "sandwich", 
               "orange", "broccoli", "carrot", "hot dog", "pizza", "donut", "cake", "chair", "couch", "potted plant", "bed", 
               "dining table", "toilet", "tv", "laptop", "mouse", "remote", "keyboard", "cell phone", "microwave", "oven", 
               "toaster", "sink", "refrigerator", "book", "clock", "vase", "scissors", "teddy bear", "hair drier", "toothbrush"]
    
    # Vegetation classes
    vegetation_class_ids = [
        classes.index("potted plant") if "potted plant" in classes else -1,
        classes.index("apple") if "apple" in classes else -1,
        classes.index("orange") if "orange" in classes else -1,
        classes.index("broccoli") if "broccoli" in classes else -1,
        classes.index("carrot") if "carrot" in classes else -1,
        classes.index("banana") if "banana" in classes else -1
    ]
    
    vegetation_class_ids = [id for id in vegetation_class_ids if id != -1]
    
    # Define colors for visualization
    colors = {
        classes.index("potted plant"): (0, 255, 0) if "potted plant" in classes else (0, 255, 0),
        classes.index("apple"): (0, 100, 255) if "apple" in classes else (0, 100, 255),
        classes.index("orange"): (0, 165, 255) if "orange" in classes else (0, 165, 255),
        classes.index("broccoli"): (0, 255, 100) if "broccoli" in classes else (0, 255, 100),
        classes.index("carrot"): (0, 200, 100) if "carrot" in classes else (0, 200, 100),
        classes.index("banana"): (0, 255, 255) if "banana" in classes else (0, 255, 255)
    }
    
    # Alternative implementation using a simpler detection approach
    output_image = image.copy()
    
    # Use a direct object detection model
    from pathlib import Path
    weights_dir = Path("yolo")
    weights_dir.mkdir(exist_ok=True)
    
    # Use YOLOv4 which has better compatibility with OpenCV
    weights_path = weights_dir / "yolov4.weights"
    cfg_path = weights_dir / "yolov4.cfg"
    
    if not weights_path.exists() or not cfg_path.exists():
        print("Downloading YOLOv4 model...")
        urllib.request.urlretrieve("https://github.com/AlexeyAB/darknet/releases/download/darknet_yolo_v3_optimal/yolov4.weights", 
                                  str(weights_path))
        urllib.request.urlretrieve("https://raw.githubusercontent.com/AlexeyAB/darknet/master/cfg/yolov4.cfg", 
                                  str(cfg_path))
    
    # Load the network
    net = cv2.dnn.readNetFromDarknet(str(cfg_path), str(weights_path))
    
    # Specify the output layers
    out_layer_names = net.getUnconnectedOutLayersNames()
    
    # Prepare the image
    blob = cv2.dnn.blobFromImage(image, 1/255.0, (416, 416), swapRB=True, crop=False)
    net.setInput(blob)
    
    # Run inference
    outputs = net.forward(out_layer_names)
    
    # Get bounding boxes, confidences, and class IDs
    boxes = []
    confidences = []
    class_ids = []
    
    for output in outputs:
        for detection in output:
            scores = detection[5:]
            class_id = np.argmax(scores)
            confidence = scores[class_id]
            
            # Filter for vegetation classes
            if confidence > 0.5 and (class_id in [64, 47, 73, 49]):  # potted plant, tree, apple, orange in YOLO
                # Scale the bounding box coordinates to the image size
                box = detection[0:4] * np.array([width, height, width, height])
                centerX, centerY, box_width, box_height = box.astype("int")
                
                # Calculate the top-left corner
                x = int(centerX - (box_width / 2))
                y = int(centerY - (box_height / 2))
                
                boxes.append([x, y, int(box_width), int(box_height)])
                confidences.append(float(confidence))
                class_ids.append(class_id)
    
    # Apply non-maximum suppression
    indices = cv2.dnn.NMSBoxes(boxes, confidences, 0.5, 0.4)
    
    # YOLO class names
    yolo_classes = ["person", "bicycle", "car", "motorbike", "aeroplane", "bus", "train", "truck", "boat", "traffic light", 
                   "fire hydrant", "stop sign", "parking meter", "bench", "bird", "cat", "dog", "horse", "sheep", "cow", 
                   "elephant", "bear", "zebra", "giraffe", "backpack", "umbrella", "handbag", "tie", "suitcase", "frisbee", 
                   "skis", "snowboard", "sports ball", "kite", "baseball bat", "baseball glove", "skateboard", "surfboard", 
                   "tennis racket", "bottle", "wine glass", "cup", "fork", "knife", "spoon", "bowl", "banana", "apple", 
                   "sandwich", "orange", "broccoli", "carrot", "hot dog", "pizza", "donut", "cake", "chair", "sofa", 
                   "pottedplant", "bed", "dining table", "toilet", "tvmonitor", "laptop", "mouse", "remote", "keyboard", 
                   "cell phone", "microwave", "oven", "toaster", "sink", "refrigerator", "book", "clock", "vase", "scissors", 
                   "teddy bear", "hair drier", "toothbrush"]
    
    # Define vegetation classes in YOLO
    yolo_vegetation = ["pottedplant", "apple", "orange", "banana", "broccoli", "carrot"]
    vegetation_indices = [yolo_classes.index(cls) for cls in yolo_vegetation if cls in yolo_classes]
    
    # Colors for YOLO classes
    yolo_colors = {
        yolo_classes.index("pottedplant"): (0, 255, 0) if "pottedplant" in yolo_classes else (0, 255, 0),
        yolo_classes.index("apple"): (0, 100, 255) if "apple" in yolo_classes else (0, 100, 255),
        yolo_classes.index("orange"): (0, 165, 255) if "orange" in yolo_classes else (0, 165, 255),
        yolo_classes.index("banana"): (0, 255, 255) if "banana" in yolo_classes else (0, 255, 255),
        yolo_classes.index("broccoli"): (0, 255, 100) if "broccoli" in yolo_classes else (0, 255, 100),
        yolo_classes.index("carrot"): (0, 200, 100) if "carrot" in yolo_classes else (0, 200, 100)
    }
    
    vegetation_count = 0
    vegetation_areas = []
    
    # Draw the filtered detections
    if len(indices) > 0:
        for i in indices.flatten():
            # Check if the detection is vegetation
            class_id = class_ids[i]
            if class_id in vegetation_indices:
                vegetation_count += 1
                
                # Get the box coordinates
                x, y, w, h = boxes[i]
                
                # Calculate area
                area = w * h
                vegetation_areas.append(area)
                
                # Draw the bounding box
                color = yolo_colors.get(class_id, (0, 255, 0))  # Default to green
                cv2.rectangle(output_image, (x, y), (x + w, y + h), color, 2)
                
                # Add label
                label = f"{yolo_classes[class_id]}: {confidences[i]:.2f}"
                cv2.putText(output_image, label, (x, y - 5), cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 2)
    
    # Convert to RGB for matplotlib
    output_image_rgb = cv2.cvtColor(output_image, cv2.COLOR_BGR2RGB)
    
    # Display results
    plt.figure(figsize=(12, 8))
    plt.imshow(output_image_rgb)
    plt.title(f"Tree/Vegetation Detection: {vegetation_count} instances")
    plt.axis('off')
    
    if output_path:
        plt.savefig(output_path, bbox_inches='tight')
        print(f"Detection results saved to {output_path}")
    
    plt.show()
    
    # Print statistics
    print(f"Detected {vegetation_count} vegetation instances")
    
    if vegetation_areas:
        avg_area = np.mean(vegetation_areas)
        print(f"Average vegetation area: {avg_area:.2f} pixels")
    
    return {
        'count': vegetation_count,
        'areas': vegetation_areas,
        'processed_image': output_image_rgb
    }

# %% [markdown]
# ## Model Configuration
#
# Define the configuration for the Mask R-CNN model as specified in the paper.

# %%
class TreeCrownConfig(Config):
    """Configuration for training on the tree crown dataset.
    Derives from the base Config class and overrides specific values.
    """
    # Give the configuration a recognizable name
    NAME = "tree_crown"
    
    # Number of classes (including background)
    NUM_CLASSES = 1 + 1  # Background + Tree Crown
    
    # Number of training steps per epoch
    STEPS_PER_EPOCH = 100
    
    # Number of validation steps to run at the end of every training epoch
    VALIDATION_STEPS = 50
    
    # Learning rate and momentum (as described in the paper)
    LEARNING_RATE = 0.001
    
    # Backbone architecture for feature extraction
    BACKBONE = "resnet101"
    
    # Input image resizing - keep images with their original aspect ratio
    # and enforce a maximum size limit
    IMAGE_RESIZE_MODE = "square"
    IMAGE_MIN_DIM = 800
    IMAGE_MAX_DIM = 1024
    
    # ROIs below this threshold are discarded
    DETECTION_MIN_CONFIDENCE = 0.7
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 class TreeCrownConfig(Config):
#       2     """Configuration for training on the tree crown dataset.
#       3     Derives from the base Config class and overrides specific values.
#       4     """
#       5     # Give the configuration a recognizable name
#
# NameError: name 'Config' is not defined

# %% [markdown]
# ## Dataset Handler
#
# The TreeCrownDataset class manages the dataset loading and preprocessing.

# %%
class TreeCrownDataset(utils.Dataset):
    def load_tree_crowns(self, dataset_dir, subset):
        """Load a subset of the Tree Crown dataset.
        dataset_dir: Root directory of the dataset.
        subset: Subset to load: train or val
        """
        # Add classes. We have only one class to add.
        self.add_class("tree_crown", 1, "tree_crown")
        
        # Train or validation dataset?
        assert subset in ["train", "val"]
        dataset_dir = os.path.join(dataset_dir, subset)
        
        # Load annotations
        # LabelMe format (poly format annotations)
        annotations = self.load_labelme_annotations(dataset_dir)
        
        for a in annotations:
            # Get the x, y coordinates of points of the polygons that make up
            # the outline of each object instance
            polygons = a['polygons']
            image_path = os.path.join(dataset_dir, a['filename'])
            
            # Load the image
            image = skimage.io.imread(image_path)
            height, width = image.shape[:2]
            
            self.add_image(
                "tree_crown",
                image_id=a['filename'],  # use file name as a unique image id
                path=image_path,
                width=width, height=height,
                polygons=polygons)
    
    def load_labelme_annotations(self, dataset_dir):
        """Load LabelMe annotations for tree crown polygons.
        This is specifically designed for the annotation format
        used in the paper with Labelme tool.
        """
        # Implementation would depend on specific format of annotations
        # For this example, assuming we have a JSON file for each image
        # with polygon coordinates for tree crowns
        
        annotations = []
        
        # Scan through all files in the directory
        for filename in os.listdir(dataset_dir):
            if filename.endswith('.json'):  # Labelme annotations are typically JSON
                json_path = os.path.join(dataset_dir, filename)
                
                # Parse the JSON file
                with open(json_path) as f:
                    data = json.load(f)
                
                # Extract image filename from JSON
                image_filename = data['imagePath']
                
                # Extract polygons - adapt this to match actual Labelme format
                polygons = []
                for shape in data['shapes']:
                    if shape['label'] == 'tree_crown':
                        # Convert points to array format
                        points = np.array(shape['points'], dtype=np.int32)
                        polygons.append(points)
                
                annotations.append({
                    'filename': image_filename,
                    'polygons': polygons
                })
        
        return annotations
    
    def load_mask(self, image_id):
        """Generate instance masks for an image.
        Returns:
        masks: A bool array of shape [height, width, instance count] with
            one mask per instance.
        class_ids: a 1D array of class IDs of the instance masks.
        """
        # If not a tree crown dataset image, delegate to parent class.
        image_info = self.image_info[image_id]
        if image_info["source"] != "tree_crown":
            return super(self.__class__, self).load_mask(image_id)
        
        # Convert polygons to a bitmap mask of shape
        # [height, width, instance_count]
        info = self.image_info[image_id]
        mask = np.zeros([info["height"], info["width"], len(info["polygons"])],
                       dtype=np.uint8)
        
        for i, p in enumerate(info["polygons"]):
            # Get indexes of pixels inside the polygon and set them to 1
            rr, cc = skimage.draw.polygon(p[:, 1], p[:, 0])
            mask[rr, cc, i] = 1
        
        # Return mask, and array of class IDs of each instance
        return mask.astype(np.bool), np.ones([mask.shape[-1]], dtype=np.int32)
    
    def image_reference(self, image_id):
        """Return the path of the image."""
        info = self.image_info[image_id]
        if info["source"] == "tree_crown":
            return info["path"]
        else:
            super(self.__class__, self).image_reference(image_id)

# %% [markdown]
# ## Image Splitting Function
#
# This function divides large satellite images into smaller sub-images as described in the paper.

# %%
def split_image(image_path, output_dir, tile_size=(935, 910)):
    """Split a large Google Earth image into smaller sub-images
    as described in the paper.
    
    Args:
        image_path: Path to the large image
        output_dir: Directory to save the sub-images
        tile_size: Size of the sub-images (width, height)
    """
    # Create output directory if it doesn't exist
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
    
    # Load the image
    img = cv2.imread(image_path)
    h, w = img.shape[:2]
    
    # Calculate number of tiles
    n_h = math.ceil(h / tile_size[1])
    n_w = math.ceil(w / tile_size[0])
    
    print(f"Splitting image of size {w}x{h} into {n_w}x{n_h} tiles")
    
    # Split the image
    count = 0
    for i in range(n_h):
        for j in range(n_w):
            x = j * tile_size[0]
            y = i * tile_size[1]
            
            # Handle edge cases
            x_end = min(x + tile_size[0], w)
            y_end = min(y + tile_size[1], h)
            
            # Extract tile
            tile = img[y:y_end, x:x_end]
            
            # Save tile
            tile_path = os.path.join(output_dir, f"tile_{count:03d}.jpg")
            cv2.imwrite(tile_path, tile)
            count += 1
    
    print(f"Split image into {count} tiles")
    return count

# Example usage
# split_image("large_satellite_image.jpg", "tiles/")

# %% [markdown]
# ## Model Training Function
#
# This function implements the training pipeline for the Mask R-CNN model.

# %%
def train_model(config, dataset_dir):
    """Train the Mask R-CNN model for tree crown detection.
    
    Args:
        config: TreeCrownConfig instance
        dataset_dir: Directory containing the dataset
    """
    # Create model in training mode
    model = modellib.MaskRCNN(mode="training", config=config, model_dir=MODEL_DIR)
    
    # Load COCO weights as starting point
    model.load_weights(COCO_MODEL_PATH, by_name=True, exclude=[
        "mrcnn_class_logits", "mrcnn_bbox_fc", "mrcnn_bbox", "mrcnn_mask"
    ])
    
    # Load training dataset
    dataset_train = TreeCrownDataset()
    dataset_train.load_tree_crowns(dataset_dir, "train")
    dataset_train.prepare()
    
    # Load validation dataset
    dataset_val = TreeCrownDataset()
    dataset_val.load_tree_crowns(dataset_dir, "val")
    dataset_val.prepare()
    
    # Train the model
    # First, train only the heads (as per the paper's approach)
    print("Training network heads")
    model.train(dataset_train, dataset_val,
               learning_rate=config.LEARNING_RATE,
               epochs=5,
               layers='heads')
    
    # Fine-tune all layers
    print("Fine-tuning all layers")
    model.train(dataset_train, dataset_val,
               learning_rate=config.LEARNING_RATE / 10,
               epochs=10,
               layers='all')
    
    return model

# Example usage
# config = TreeCrownConfig()
# model = train_model(config, "dataset_directory/")

# %% [markdown]
# ## Detection Function
#
# This function detects tree crowns in new images using the trained model.

# %%
def detect_tree_crowns(model, image_path, output_path=None):
    """Detect tree crowns in an image and save the result.
    
    Args:
        model: Trained Mask R-CNN model
        image_path: Path to the input image
        output_path: Path to save the output visualization
        
    Returns:
        Detection results
    """
    # Read the image
    image = skimage.io.imread(image_path)
    
    # Detect tree crowns
    results = model.detect([image], verbose=1)
    r = results[0]
    
    # Visualize results
    fig = plt.figure(figsize=(12, 12))
    visualize.display_instances(
        image, r['rois'], r['masks'], r['class_ids'],
        ['BG', 'Tree Crown'], r['scores'],
        title="Tree Crown Detection",
        figsize=(12, 12)
    )
    
    # Save the figure if output_path is specified
    if output_path:
        plt.savefig(output_path)
        plt.close()
    else:
        plt.show()
    
    return r

# Example usage
# detect_tree_crowns(model, "test_image.jpg", "result.png")

# %% [markdown]
# ## Results Analysis
#
# This function analyzes the detection results to get statistics about tree crowns.

# %%
def analyze_results(results):
    """Analyze the detection results to get statistics about tree crowns.
    
    Args:
        results: List of detection results for multiple images
    
    Returns:
        Dictionary with statistics
    """
    total_trees = 0
    total_area = 0
    area_distribution = {}
    bin_size = 50  # bin size in m²
    
    for r in results:
        n_trees = r['masks'].shape[-1]
        total_trees += n_trees
        
        # Calculate area for each tree crown
        for i in range(n_trees):
            mask = r['masks'][:, :, i]
            area = np.sum(mask) * (0.27**2)  # Convert pixels to m² (0.27m resolution)
            total_area += area
            
            # Update area distribution
            bin_idx = int(area / bin_size)
            if bin_idx not in area_distribution:
                area_distribution[bin_idx] = 0
            area_distribution[bin_idx] += 1
    
    # Prepare distribution data for plotting
    area_bins = []
    tree_counts = []
    for bin_idx in sorted(area_distribution.keys()):
        min_area = bin_idx * bin_size
        max_area = (bin_idx + 1) * bin_size
        area_bins.append(f"[{min_area}, {max_area})")
        tree_counts.append(area_distribution[bin_idx])
    
    stats = {
        'total_trees': total_trees,
        'total_area': total_area,
        'area_distribution': {
            'bins': area_bins,
            'counts': tree_counts
        }
    }
    
    return stats

def plot_area_distribution(stats):
    """Plot the distribution of tree crown areas.
    
    Args:
        stats: Statistics dictionary returned by analyze_results
    """
    plt.figure(figsize=(12, 6))
    plt.bar(stats['area_distribution']['bins'], 
           stats['area_distribution']['counts'])
    plt.xlabel('Crown Area (m²)')
    plt.ylabel('Number of Trees')
    plt.title('Distribution of Tree Crown Areas')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Complete Workflow Example
#
# Here's an example of a complete workflow using the functions defined above.

# %%
# Example workflow - uncomment and modify as needed

# 1. Split a large satellite image into smaller tiles
# split_image("large_satellite_image.jpg", "tiles/")

# 2. Create and train the model
# config = TreeCrownConfig()
# model = train_model(config, "dataset_directory/")

# 3. Load a trained model for inference
# config = TreeCrownConfig()
# config.BATCH_SIZE = 1  # For inference
# model = modellib.MaskRCNN(mode="inference", config=config, model_dir=MODEL_DIR)
# weights_path = model.find_last()  # Find last trained weights
# model.load_weights(weights_path, by_name=True)

# 4. Process all images in a directory
# results = []
# input_dir = "test_images/"
# output_dir = "results/"
# os.makedirs(output_dir, exist_ok=True)
# for filename in os.listdir(input_dir):
#     if filename.endswith(('.jpg', '.jpeg', '.png')):
#         image_path = os.path.join(input_dir, filename)
#         output_path = os.path.join(output_dir, f"result_{os.path.splitext(filename)[0]}.png")
#         print(f"Processing {image_path}")
#         result = detect_tree_crowns(model, image_path, output_path)
#         results.append(result)

# 5. Analyze and visualize results
# stats = analyze_results(results)
# print(f"Total trees detected: {stats['total_trees']}")
# print(f"Total crown area: {stats['total_area']:.2f} m²")
# plot_area_distribution(stats)

# %% [markdown]
# ## Processing a Single Image Example
#
# You can use this cell to process a single test image.

# %%
# Example for processing a single image
# config = TreeCrownConfig()
# config.BATCH_SIZE = 1  # For inference
# model = modellib.MaskRCNN(mode="inference", config=config, model_dir=MODEL_DIR)
# weights_path = model.find_last()  # Find last trained weights
# model.load_weights(weights_path, by_name=True)

# result = detect_tree_crowns(model, "test_image.jpg")
# print(f"Detected {result['masks'].shape[-1]} trees")

# # Calculate average crown area
# areas = []
# for i in range(result['masks'].shape[-1]):
#     mask = result['masks'][:, :, i]
#     area = np.sum(mask) * (0.27**2)  # Convert pixels to m² (0.27m resolution)
#     areas.append(area)

# avg_area = np.mean(areas) if areas else 0
# print(f"Average crown area: {avg_area:.2f} m²")
